# %% [markdown]
# # Importing the Required Dependencies

# %%
# Import Python Standard Library dependencies

import os
from functools import partial
from pathlib import Path
from typing import Tuple, List, Dict, Optional
from collections import OrderedDict
import xml.etree.ElementTree as ET
from typing import Any, Dict, Optional

# Import utility functions
from cjm_pil_utils.core import get_img_files
from cjm_psl_utils.core import download_file, file_extract
from cjm_pytorch_utils.core import pil_to_tensor, tensor_to_pil, get_torch_device, set_seed, denorm_img_tensor, move_data_to_device
from cjm_torchvision_tfms.core import ResizeMax, PadSquare, CustomRandomIoUCrop

# Import the distinctipy module
from distinctipy import distinctipy

# Import matplotlib for creating plots
import matplotlib.pyplot as plt

# Import numpy
import numpy as np

# Import the pandas package
import pandas as pd

# Do not truncate the contents of cells and display all rows and columns
pd.set_option('max_colwidth', None, 'display.max_rows', None, 'display.max_columns', None)

# Import PIL for image manipulation
from PIL import Image

# Import PyTorch dependencies
import torch
from torch import Tensor
from torch.utils.data import Dataset, DataLoader

# Import torchvision dependencies
import torchvision
torchvision.disable_beta_transforms_warning()
from torchvision.tv_tensors import BoundingBoxes
from torchvision.utils import draw_bounding_boxes
import torchvision.transforms.v2  as transforms
from torchvision.models.detection.roi_heads import fastrcnn_loss
from torchvision.models.detection.rpn import concat_box_prediction_layers
from torch.utils.tensorboard import SummaryWriter
from torch.amp import autocast

# Import tqdm for progress bar
from tqdm.auto import tqdm
from engine import train_one_epoch, evaluate
import utils

# %%
# 데이터 세트 저장 경로 정의
dataset_path =Path("./validsets/")
model = torchvision.models.detection.fasterrcnn_resnet50_fpn_v2(weight='DEFAULT', max_size=1920)

# %% [markdown]
# ### CVAT 주석을 파싱하기위한 함수 정의(Define a function to parse the CVAT XML annotations)

# %%
def parse_cvat_bbox_xml(xml_content):
    """
    CVAT 바운딩 박스 주석 파일의 주어진 XML 콘텐츠를 구문 분석하고
    판다 데이터프레임으로 변환합니다.

    이 함수는 XML 콘텐츠를 처리하여 각 이미지와 관련 바운딩 박스에 대한 정보를 추출합니다.
    이미지 및 관련 바운딩 박스에 대한 정보를 추출합니다. 그런 다음 데이터는
    데이터 프레임으로 구조화하여 조작과 분석이 용이하도록 합니다.

    Parameters:
    xml_content (str): A string containing the XML content from a CVAT bounding box
                       annotation file.

    Returns:
    pandas.DataFrame: A DataFrame where each row represents an image and contains
                      the following columns:
                      - Image ID (int): The unique identifier of the image.
                      - Image Name (str): The name of the image.
                      - Width (int): The width of the image in pixels.
                      - Height (int): The height of the image in pixels.
                      - Boxes (list): A list of dictionaries, where each dictionary
                                      represents a bounding box with keys 'Label',
                                      'xtl', 'ytl', 'xbr', and 'ybr' indicating the
                                      label and coordinates of the box.
    """

    # XML 콘텐츠 구문 분석
    root = ET.fromstring(xml_content)
    data = {}

    # XML의 각 이미지 요소를 반복합니다.
    for image in root.findall('image'):
        # Extract image attributes
        image_id = image.get('id')
        image_name = image.get('name')
        width = image.get('width')
        height = image.get('height')

        # 이미지 데이터를 저장할 사전을 초기화합니다.
        image_data = {
            'Image ID': int(image_id),
            'Image Name': image_name,
            'Width': int(width),
            'Height': int(height),
            'Boxes': []
        }

        # 이미지 내의 각 바운딩 박스 요소를 반복합니다.
        for box in image.findall('box'):
            # Extract box attributes
            label = box.get('label')
            xtl = float(box.get('xtl'))
            ytl = float(box.get('ytl'))
            xbr = float(box.get('xbr'))
            ybr = float(box.get('ybr'))

            # 상자 데이터에 대한 사전을 구축합니다.
            box_data = {
                'Label': label,
                'xtl': xtl,
                'ytl': ytl,
                'xbr': xbr,
                'ybr': ybr
            }

            # 이미지의 '박스' 목록에 박스 데이터를 추가합니다.
            image_data['Boxes'].append(box_data)

        # 이미지 데이터를 데이터 사전의 ID에 매핑합니다.
        data[image_id] = image_data

    # 데이터 사전을 데이터 프레임으로 변환하고 반환합니다.
    return pd.DataFrame.from_dict(data, orient='index')

# %%
import os

# 이미지 리스팅
# img_dir = dataset_path/'images'
img_dir = './3_1'
img_dict = {
    file.stem : file
    for file in get_img_files(img_dir)
}

# annotation 리스팅
annotation_dir_path = './annotation'
dir_list = os.listdir(annotation_dir_path)

start = True
for xml_file in dir_list:
    print(f'{annotation_dir_path}/{xml_file}')
    if start:
         with open(f'{annotation_dir_path}/{xml_file}', 'r', encoding='utf-8') as file:
            xml_content = file.read()
            annotation_df = parse_cvat_bbox_xml(xml_content)
            start = False
    else:
        with open(f'{annotation_dir_path}/{xml_file}', 'r', encoding='utf-8') as file:
            xml_content = file.read()
            annotation_df = pd.concat([annotation_df, parse_cvat_bbox_xml(xml_content)], ignore_index=True)

annotation_df['Image ID'] = annotation_df['Image Name'].apply(lambda x: x.split('.png')[0])


annotation_df = annotation_df.set_index('Image ID') # 새 '이미지 ID' 열을 데이터프레임의 인덱스로 설정
boxes_df = annotation_df['Boxes'].explode().to_frame().Boxes.apply(pd.Series)

class_names = boxes_df['Label'].unique().tolist() # 'annotation_df' 데이터프레임에서 고유 레이블 목록 가져오기

class_to_idx = {c: i for i, c in enumerate(class_names)}

label_dic = {}
label_dic['car']=1
label_dic['truck']=2
label_dic['bus']=3
# Out:
# ./annotation/Cheonan_gangjeong_20201019_1600_MON_15m_RH_highway_TW3_sunny_FHD.xml
# ./annotation/Cheonan_gangjeong_20201019_1700_MON_15m_NH_highway_TW3_sunny_FHD.xml

# %%
def make_prediction(preds, threshold):
    
    for id in range(len(preds)) :
        idx_list = []

        for idx, score in enumerate(preds[id]['scores']) :
            if score > threshold : 
                idx_list.append(idx)

        preds[id]['boxes'] = preds[id]['boxes'][idx_list]
        preds[id]['labels'] = preds[id]['labels'][idx_list]
        preds[id]['scores'] = preds[id]['scores'][idx_list]
        
    return preds

def makeBox(image_raw,bbox,objects):
  image = image_raw.copy()
  for i in range(len(objects)):
    cv2.rectangle(image,(int(bbox[i][0]),int(bbox[i][1])),(int(bbox[i][2]),int(bbox[i][3])),color = (0,255,0),thickness = 1)
    cv2.putText(image, objects[i], (int(bbox[i][0]), int(bbox[i][1])-10), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0,255,0), 2) # 크기, 색, 굵기
  return image

def make_info_txt(file_name, object_name, bbox, mode, scores = None):
    file_name = str(file_name)    
    file_name = file_name.split("\\")[-1]
    if mode == 'gt':
        print(bbox)
        boxx = []
        labels = []
        for item in range(len(bbox)):
            box = [bbox[item]['xtl']]
            box.append(bbox[item]['ytl'])
            box.append(bbox[item]['xbr'])
            box.append(bbox[item]['ybr'])
            boxx.append(box)
            labels.append(bbox[item]['Label'])


        with open("validsets/mAP/input/ground-truth/{}.txt".format(file_name[:-4]),"w") as f:
            for i in range(len(labels)):
                f.write("{} ".format(labels[i])+" ".join(map(str,map(int,boxx[i])))+"\n")
    
    if mode == 'rt':
        assert scores != None
        with open("validsets/mAP/input/detection-results/{}.txt".format(file_name[:-4]),"w") as f:
            for i in range(len(object_name)):
                f.write("{} ".format(object_name[i])+"{} ".format(scores[i])+" ".join(map(str,map(int,bbox[i])))+"\n")
import cv2
def evaluation(img_dict, annotation_df, new = False):
    # 폴더생성
    if new == True:
        print("Clear Directory")
        filelist = [ f for f in os.listdir("./validsets/mAP/input/ground-truth/")]
        for f in filelist:
            os.remove(os.path.join("./validsets/mAP/input/ground-truth/", f))     
        filelist = [ f for f in os.listdir("./validsets/mAP/input/detection-results/")]
        for f in filelist:
            os.remove(os.path.join("./validsets/mAP/input/detection-results/", f)) 

    # 데이터 파싱 후 평가
    img_key = list(img_dict.keys())
    for i in range(len(img_key)):
        img_id = img_key[i]
        img_name = img_dict[img_id]
        img_path = f"{img_name}"
        img = Image.open(img_path).convert("RGB")
        img = img.resize((1920, 1080))
        to_tensor = torchvision.transforms.ToTensor()
        test_image = to_tensor(img).unsqueeze(0)
        model.eval()
        with torch.no_grad():
            prediction = model(test_image.to(device))

        prediction=make_prediction(prediction, 0.8)

        boxes = prediction[0]['boxes']
        labels = prediction[0]['labels']
        scores = prediction[0]['scores']

        object_name = []
        for lb in labels:
            object_name.append([k for k, v in label_dic.items() if v == lb][0])
        make_info_txt(img_name, object_name, boxes, mode='rt', scores = scores)
        make_info_txt(img_name, object_name, annotation_df.loc[img_id, 'Boxes'], mode='gt')
        img = np.array(Image.open(img_path).convert("RGB"))
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB ) 

        im = makeBox(img,boxes,object_name)
        
        cv2.imshow("image",im)
        cv2.waitKey(1)

    print("Result")
    f = os.popen("python /dataset/mAP/main.py --no-animation ") #openCV작동 안해서 --no-animation
    print(f.read())

# %%
def evaluation2(img_dict):
    # 폴더생성
    if new == True:
        print("Clear Directory")
        filelist = [ f for f in os.listdir("./validsets/mAP/input/ground-truth/")]
        for f in filelist:
            os.remove(os.path.join("./validsets/mAP/input/ground-truth/", f))     
        filelist = [ f for f in os.listdir("./validsets/mAP/input/detection-results/")]
        for f in filelist:
            os.remove(os.path.join("./validsets/mAP/input/detection-results/", f)) 

    # 데이터 파싱 후 평가
    img_key = list(img_dict.keys())
    for i in range(len(img_key)):
        img_id = img_key[i]
        img_name = img_dict[img_id]
        img_path = f"{img_name}"
        img = Image.open(img_path).convert("RGB")
        img = img.resize((1920, 1080))
        to_tensor = torchvision.transforms.ToTensor()
        test_image = to_tensor(img).unsqueeze(0)
        model.eval()
        with torch.no_grad():
            prediction = model(test_image.to(device))

        prediction=make_prediction(prediction, 0.5)

        boxes = prediction[0]['boxes']
        labels = prediction[0]['labels']
        scores = prediction[0]['scores']

        object_name = []
        for lb in labels:
            object_name.append([k for k, v in label_dic.items() if v == lb][0])
        make_info_txt(img_name, object_name, boxes, mode='rt', scores = scores)
        make_info_txt(img_name, object_name, annotation_df.loc[img_id, 'Boxes'], mode='gt')
        img = np.array(Image.open(img_path).convert("RGB"))
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB ) 

        im = makeBox(img,boxes,object_name)
        
        cv2.imshow("image",im)
        cv2.waitKey(2)

    print("Result")
    # f = os.popen("python /dataset/mAP/main.py --no-animation ") #openCV작동 안해서 --no-animation
    print(f.read())

# %%
if torch.cuda.is_available():
  device = torch.device('cuda')
else:
  device = torch.device('cpu')

from torchvision.models.detection.faster_rcnn import FastRCNNPredictor
model = torchvision.models.detection.fasterrcnn_resnet50_fpn_v2(weights='DEFAULT', max_size=1920)

num_classes = 4
in_features = model.roi_heads.box_predictor.cls_score.in_features
model.roi_heads.box_predictor = FastRCNNPredictor(in_features, num_classes)

model.to(device)
model.load_state_dict(torch.load("fasterrcnn_resnet50_fpn_v2.pth",map_location=device)) #epoch지정
# Out:
# <All keys matched successfully>

# %%
evaluation(img_dict, annotation_df, new = True)
import time
time.sleep(5)
cv2.destroyAllWindows()
# Out:
# Clear Directory
# [{'Label': 'car', 'xtl': 1187.0, 'ytl': 755.0, 'xbr': 1296.0, 'ybr': 843.0}, {'Label': 'truck', 'xtl': 418.0, 'ytl': 363.0, 'xbr': 469.0, 'ybr': 435.0}, {'Label': 'truck', 'xtl': 1185.0, 'ytl': 597.0, 'xbr': 1362.0, 'ybr': 778.0}, {'Label': 'truck', 'xtl': 1380.0, 'ytl': 709.0, 'xbr': 1667.0, 'ybr': 936.0}, {'Label': 'truck', 'xtl': 851.0, 'ytl': 565.0, 'xbr': 909.0, 'ybr': 621.0}, {'Label': 'truck', 'xtl': 882.0, 'ytl': 438.0, 'xbr': 976.0, 'ybr': 551.0}, {'Label': 'truck', 'xtl': 384.0, 'ytl': 273.0, 'xbr': 414.0, 'ybr': 311.0}, {'Label': 'truck', 'xtl': 677.0, 'ytl': 333.0, 'xbr': 727.0, 'ybr': 390.0}, {'Label': 'truck', 'xtl': 718.0, 'ytl': 362.0, 'xbr': 767.0, 'ybr': 418.0}, {'Label': 'bus', 'xtl': 1503.0, 'ytl': 928.0, 'xbr': 1813.0, 'ybr': 1077.0}, {'Label': 'car', 'xtl': 692.0, 'ytl': 560.0, 'xbr': 752.0, 'ybr': 611.0}, {'Label': 'car', 'xtl': 1049.0, 'ytl': 659.0, 'xbr': 1120.0, 'ybr': 713.0}, {'Label': 'car', 'xtl': 550.0, 'ytl': 512.0, 'xbr': 596.0, 'ybr': 553.0}, {'Label': 'car', 'xtl': 838.0, 'ytl': 508.0, 'xbr': 884.0, 'ybr': 541.0}, {'Label': 'car', 'xtl': 793.0, 'ytl': 691.0, 'xbr': 868.0, 'ybr': 754.0}, {'Label': 'car', 'xtl': 482.0, 'ytl': 390.0, 'xbr': 519.0, 'ybr': 422.0}, {'Label': 'car', 'xtl': 690.0, 'ytl': 439.0, 'xbr': 729.0, 'ybr': 471.0}, {'Label': 'car', 'xtl': 497.0, 'ytl': 417.0, 'xbr': 534.0, 'ybr': 449.0}, {'Label': 'car', 'xtl': 917.0, 'ytl': 556.0, 'xbr': 972.0, 'ybr': 596.0}, {'Label': 'car', 'xtl': 738.0, 'ytl': 479.0, 'xbr': 782.0, 'ybr': 513.0}, {'Label': 'car', 'xtl': 602.0, 'ytl': 585.0, 'xbr': 666.0, 'ybr': 642.0}, {'Label': 'car', 'xtl': 955.0, 'ytl': 671.0, 'xbr': 1030.0, 'ybr': 724.0}]
# [{'Label': 'truck', 'xtl': 851.0, 'ytl': 914.0, 'xbr': 983.0, 'ybr': 1079.0}, {'Label': 'car', 'xtl': 764.0, 'ytl': 513.0, 'xbr': 808.0, 'ybr': 550.0}, {'Label': 'truck', 'xtl': 1000.0, 'ytl': 507.0, 'xbr': 1121.0, 'ybr': 627.0}, {'Label': 'truck', 'xtl': 418.0, 'ytl': 372.0, 'xbr': 465.0, 'ybr': 430.0}, {'Label': 'car', 'xtl': 885.19, 'ytl': 834.83, 'xbr': 991.82, 'ybr': 921.81}, {'Label': 'bus', 'xtl': 641.13, 'ytl': 342.89, 'xbr': 687.89, 'ybr': 389.65}, {'Label': 'car', 'xtl': 501.0, 'ytl': 444.0, 'xbr': 544.0, 'ybr': 484.0}, {'Label': 'truck', 'xtl': 863.0, 'ytl': 515.0, 'xbr': 915.0, 'ybr': 568.0}, {'Label': 'car', 'xtl': 696.0, 'ytl': 448.0, 'xbr': 734.0, 'ybr': 480.0}, {'Label': 'car', 'xtl': 753.0, 'ytl': 439.0, 'xbr': 791.0, 'ybr': 468.0}, {'Label': 'truck', 'xtl': 698.52, 'ytl': 343.19, 'xbr': 741.52, 'ybr': 394.19}, {'Label': 'car', 'xtl': 991.0, 'ytl': 621.0, 'xbr': 1049.0, 'ybr': 670.0}, {'Label': 'car', 'xtl': 1170.0, 'ytl': 671.0, 'xbr': 1252.0, 'ybr': 729.0}, {'Label': 'truck', 'xtl': 611.0, 'ytl': 826.0, 'xbr': 831.0, 'ybr': 1080.0}, {'Label': 'truck', 'xtl': 730.7, 'ytl': 357.52, 'xbr': 780.7, 'ybr': 415.5}, {'Label': 'car', 'xtl': 578.0, 'ytl': 561.0, 'xbr': 636.0, 'ybr': 608.0}, {'Label': 'car', 'xtl': 906.0, 'ytl': 620.0, 'xbr': 978.0, 'ybr': 676.0}, {'Label': 'car', 'xtl': 532.0, 'ytl': 482.0, 'xbr': 581.0, 'ybr': 521.0}, {'Label': 'car', 'xtl': 1169.0, 'ytl': 849.0, 'xbr': 1268.0, 'ybr': 924.0}]
# [{'Label': 'car', 'xtl': 525.0, 'ytl': 461.0, 'xbr': 567.0, 'ybr': 501.0}, {'Label': 'car', 'xtl': 801.0, 'ytl': 691.0, 'xbr': 885.0, 'ybr': 768.0}, {'Label': 'car', 'xtl': 649.0, 'ytl': 517.0, 'xbr': 700.0, 'ybr': 561.0}, {'Label': 'car', 'xtl': 1406.0, 'ytl': 925.0, 'xbr': 1533.0, 'ybr': 1006.0}, {'Label': 'car', 'xtl': 603.0, 'ytl': 459.0, 'xbr': 648.0, 'ybr': 495.0}, {'Label': 'car', 'xtl': 514.0, 'ytl': 438.0, 'xbr': 553.0, 'ybr': 469.0}, {'Label': 'car', 'xtl': 799.0, 'ytl': 438.0, 'xbr': 836.0, 'ybr': 468.0}, {'Label': 'car', 'xtl': 560.0, 'ytl': 419.0, 'xbr': 598.0, 'ybr': 449.0}, {'Label': 'truck', 'xtl': 428.06, 'ytl': 394.64, 'xbr': 478.72, 'ybr': 457.0}, {'Label': 'car', 'xtl': 673.57, 'ytl': 414.13, 'xbr': 706.7, 'ybr': 442.38}, {'Label': 'truck', 'xtl': 714.0, 'ytl': 754.0, 'xbr': 809.0, 'ybr': 848.0}, {'Label': 'truck', 'xtl': 616.0, 'ytl': 902.0, 'xbr': 805.0, 'ybr': 1080.0}, {'Label': 'truck', 'xtl': 468.0, 'ytl': 503.0, 'xbr': 531.0, 'ybr': 589.0}, {'Label': 'truck', 'xtl': 932.0, 'ytl': 485.0, 'xbr': 1025.0, 'ybr': 575.0}, {'Label': 'truck', 'xtl': 436.0, 'ytl': 413.0, 'xbr': 506.0, 'ybr': 513.0}, {'Label': 'truck', 'xtl': 650.28, 'ytl': 315.74, 'xbr': 683.28, 'ybr': 356.74}, {'Label': 'truck', 'xtl': 876.0, 'ytl': 1010.0, 'xbr': 1021.0, 'ybr': 1080.0}]
# [{'Label': 'car', 'xtl': 570.0, 'ytl': 438.0, 'xbr': 613.0, 'ybr': 467.0}, {'Label': 'car', 'xtl': 921.0, 'ytl': 556.0, 'xbr': 978.0, 'ybr': 599.0}, {'Label': 'car', 'xtl': 737.0, 'ytl': 620.0, 'xbr': 808.0, 'ybr': 676.0}, {'Label': 'car', 'xtl': 821.0, 'ytl': 946.0, 'xbr': 943.0, 'ybr': 1051.0}, {'Label': 'car', 'xtl': 861.0, 'ytl': 521.0, 'xbr': 914.0, 'ybr': 562.0}, {'Label': 'car', 'xtl': 942.0, 'ytl': 870.7, 'xbr': 1055.8, 'ybr': 967.06}, {'Label': 'car', 'xtl': 647.0, 'ytl': 519.0, 'xbr': 698.0, 'ybr': 558.0}, {'Label': 'car', 'xtl': 1098.0, 'ytl': 696.0, 'xbr': 1173.0, 'ybr': 756.0}, {'Label': 'truck', 'xtl': 456.0, 'ytl': 330.0, 'xbr': 500.0, 'ybr': 386.0}, {'Label': 'truck', 'xtl': 417.0, 'ytl': 358.0, 'xbr': 460.0, 'ybr': 412.0}, {'Label': 'truck', 'xtl': 1672.0, 'ytl': 892.0, 'xbr': 1904.0, 'ybr': 1080.0}, {'Label': 'car', 'xtl': 758.0, 'ytl': 496.0, 'xbr': 806.0, 'ybr': 535.0}, {'Label': 'car', 'xtl': 564.0, 'ytl': 534.0, 'xbr': 618.0, 'ybr': 577.0}]
# [{'Label': 'truck', 'xtl': 731.0, 'ytl': 686.0, 'xbr': 910.0, 'ybr': 925.0}, {'Label': 'bus', 'xtl': 434.0, 'ytl': 416.0, 'xbr': 498.0, 'ybr': 497.0}, {'Label': 'truck', 'xtl': 410.0, 'ytl': 337.0, 'xbr': 446.0, 'ybr': 383.0}, {'Label': 'truck', 'xtl': 527.0, 'ytl': 441.0, 'xbr': 581.0, 'ybr': 513.0}, {'Label': 'car', 'xtl': 485.0, 'ytl': 383.0, 'xbr': 518.0, 'ybr': 412.0}, {'Label': 'car', 'xtl': 562.0, 'ytl': 421.0, 'xbr': 599.0, 'ybr': 452.0}, {'Label': 'car', 'xtl': 502.0, 'ytl': 575.0, 'xbr': 560.0, 'ybr': 629.0}, {'Label': 'car', 'xtl': 475.0, 'ytl': 498.0, 'xbr': 526.0, 'ybr': 548.0}, {'Label': 'car', 'xtl': 616.0, 'ytl': 594.0, 'xbr': 677.0, 'ybr': 647.0}, {'Label': 'car', 'xtl': 919.0, 'ytl': 570.0, 'xbr': 978.0, 'ybr': 610.0}, {'Label': 'car', 'xtl': 781.0, 'ytl': 523.0, 'xbr': 832.0, 'ybr': 563.0}, {'Label': 'car', 'xtl': 903.0, 'ytl': 796.0, 'xbr': 997.0, 'ybr': 884.0}, {'Label': 'truck', 'xtl': 712.0, 'ytl': 356.0, 'xbr': 764.0, 'ybr': 413.0}, {'Label': 'car', 'xtl': 515.0, 'ytl': 633.0, 'xbr': 577.0, 'ybr': 684.0}, {'Label': 'car', 'xtl': 665.0, 'ytl': 692.0, 'xbr': 747.0, 'ybr': 764.0}, {'Label': 'truck', 'xtl': 562.0, 'ytl': 737.0, 'xbr': 687.0, 'ybr': 907.0}]
# [{'Label': 'car', 'xtl': 520.0, 'ytl': 458.0, 'xbr': 557.0, 'ybr': 493.0}, {'Label': 'truck', 'xtl': 572.0, 'ytl': 720.0, 'xbr': 685.0, 'ybr': 879.0}, {'Label': 'truck', 'xtl': 1232.0, 'ytl': 691.0, 'xbr': 1330.0, 'ybr': 782.0}, {'Label': 'car', 'xtl': 677.0, 'ytl': 550.0, 'xbr': 735.0, 'ybr': 596.0}, {'Label': 'car', 'xtl': 567.0, 'ytl': 553.0, 'xbr': 625.0, 'ybr': 596.0}, {'Label': 'car', 'xtl': 625.0, 'ytl': 628.0, 'xbr': 699.0, 'ybr': 692.0}, {'Label': 'car', 'xtl': 1231.0, 'ytl': 902.0, 'xbr': 1333.0, 'ybr': 981.0}, {'Label': 'car', 'xtl': 1060.0, 'ytl': 981.0, 'xbr': 1182.0, 'ybr': 1077.0}, {'Label': 'car', 'xtl': 717.0, 'ytl': 758.0, 'xbr': 806.0, 'ybr': 833.0}, {'Label': 'car', 'xtl': 733.0, 'ytl': 477.0, 'xbr': 776.0, 'ybr': 510.0}, {'Label': 'car', 'xtl': 913.0, 'ytl': 1032.0, 'xbr': 1023.0, 'ybr': 1080.0}, {'Label': 'car', 'xtl': 585.0, 'ytl': 453.0, 'xbr': 625.0, 'ybr': 485.0}]
# [{'Label': 'car', 'xtl': 692.0, 'ytl': 718.0, 'xbr': 772.0, 'ybr': 780.0}, {'Label': 'car', 'xtl': 1251.0, 'ytl': 812.0, 'xbr': 1358.0, 'ybr': 886.0}, {'Label': 'car', 'xtl': 740.0, 'ytl': 635.0, 'xbr': 808.0, 'ybr': 688.0}, {'Label': 'car', 'xtl': 847.0, 'ytl': 928.0, 'xbr': 966.0, 'ybr': 1040.0}, {'Label': 'truck', 'xtl': 1049.0, 'ytl': 562.0, 'xbr': 1149.0, 'ybr': 655.0}, {'Label': 'car', 'xtl': 685.0, 'ytl': 441.0, 'xbr': 725.0, 'ybr': 474.0}, {'Label': 'car', 'xtl': 776.0, 'ytl': 464.0, 'xbr': 818.0, 'ybr': 498.0}, {'Label': 'car', 'xtl': 760.0, 'ytl': 487.0, 'xbr': 809.0, 'ybr': 525.0}, {'Label': 'car', 'xtl': 580.0, 'ytl': 438.0, 'xbr': 624.0, 'ybr': 480.0}, {'Label': 'truck', 'xtl': 398.0, 'ytl': 316.0, 'xbr': 434.0, 'ybr': 366.0}, {'Label': 'truck', 'xtl': 859.0, 'ytl': 436.0, 'xbr': 931.0, 'ybr': 514.0}, {'Label': 'truck', 'xtl': 794.0, 'ytl': 394.0, 'xbr': 857.0, 'ybr': 472.0}, {'Label': 'truck', 'xtl': 955.0, 'ytl': 559.0, 'xbr': 1049.0, 'ybr': 653.0}, {'Label': 'truck', 'xtl': 1256.0, 'ytl': 668.0, 'xbr': 1389.0, 'ybr': 788.0}]
# [{'Label': 'truck', 'xtl': 488.0, 'ytl': 554.0, 'xbr': 604.0, 'ybr': 756.0}, {'Label': 'truck', 'xtl': 510.0, 'ytl': 536.0, 'xbr': 585.0, 'ybr': 646.0}, {'Label': 'truck', 'xtl': 663.0, 'ytl': 340.0, 'xbr': 705.0, 'ybr': 386.0}, {'Label': 'truck', 'xtl': 921.0, 'ytl': 461.0, 'xbr': 1039.0, 'ybr': 580.0}, {'Label': 'truck', 'xtl': 620.05, 'ytl': 303.38, 'xbr': 651.2, 'ybr': 341.5}, {'Label': 'car', 'xtl': 748.0, 'ytl': 643.0, 'xbr': 814.0, 'ybr': 696.0}, {'Label': 'car', 'xtl': 622.0, 'ytl': 607.0, 'xbr': 689.0, 'ybr': 665.0}, {'Label': 'car', 'xtl': 892.0, 'ytl': 781.0, 'xbr': 983.0, 'ybr': 855.0}, {'Label': 'car', 'xtl': 516.0, 'ytl': 451.0, 'xbr': 560.0, 'ybr': 489.0}, {'Label': 'car', 'xtl': 587.0, 'ytl': 455.0, 'xbr': 626.0, 'ybr': 484.0}, {'Label': 'car', 'xtl': 509.0, 'ytl': 438.0, 'xbr': 549.0, 'ybr': 472.0}]
# [{'Label': 'car', 'xtl': 523.0, 'ytl': 367.0, 'xbr': 558.0, 'ybr': 400.0}, {'Label': 'car', 'xtl': 683.0, 'ytl': 427.0, 'xbr': 718.0, 'ybr': 455.0}, {'Label': 'car', 'xtl': 427.0, 'ytl': 400.0, 'xbr': 464.0, 'ybr': 432.0}, {'Label': 'car', 'xtl': 866.0, 'ytl': 1026.0, 'xbr': 1001.0, 'ybr': 1080.0}, {'Label': 'truck', 'xtl': 1609.0, 'ytl': 1033.0, 'xbr': 1738.0, 'ybr': 1080.0}, {'Label': 'truck', 'xtl': 619.0, 'ytl': 300.0, 'xbr': 660.0, 'ybr': 346.0}, {'Label': 'truck', 'xtl': 830.0, 'ytl': 439.0, 'xbr': 872.0, 'ybr': 488.0}, {'Label': 'truck', 'xtl': 763.0, 'ytl': 417.0, 'xbr': 833.0, 'ybr': 497.0}, {'Label': 'truck', 'xtl': 1366.0, 'ytl': 713.0, 'xbr': 1654.0, 'ybr': 964.0}, {'Label': 'truck', 'xtl': 919.0, 'ytl': 477.0, 'xbr': 1004.0, 'ybr': 567.0}, {'Label': 'car', 'xtl': 528.0, 'ytl': 462.0, 'xbr': 572.0, 'ybr': 500.0}, {'Label': 'car', 'xtl': 727.0, 'ytl': 807.0, 'xbr': 822.0, 'ybr': 887.0}, {'Label': 'car', 'xtl': 702.0, 'ytl': 575.0, 'xbr': 764.0, 'ybr': 629.0}, {'Label': 'car', 'xtl': 1050.0, 'ytl': 955.0, 'xbr': 1167.0, 'ybr': 1051.0}, {'Label': 'car', 'xtl': 757.0, 'ytl': 665.0, 'xbr': 830.0, 'ybr': 729.0}, {'Label': 'car', 'xtl': 460.0, 'ytl': 508.0, 'xbr': 510.0, 'ybr': 550.0}, {'Label': 'car', 'xtl': 623.0, 'ytl': 493.0, 'xbr': 669.0, 'ybr': 531.0}]
# [{'Label': 'truck', 'xtl': 714.0, 'ytl': 353.0, 'xbr': 770.0, 'ybr': 420.0}, {'Label': 'car', 'xtl': 942.0, 'ytl': 656.0, 'xbr': 1013.0, 'ybr': 711.0}, {'Label': 'car', 'xtl': 633.0, 'ytl': 400.0, 'xbr': 667.0, 'ybr': 428.0}, {'Label': 'car', 'xtl': 591.0, 'ytl': 562.0, 'xbr': 646.0, 'ybr': 605.0}, {'Label': 'car', 'xtl': 1304.0, 'ytl': 970.0, 'xbr': 1434.0, 'ybr': 1054.0}, {'Label': 'car', 'xtl': 511.0, 'ytl': 455.0, 'xbr': 555.0, 'ybr': 487.0}, {'Label': 'car', 'xtl': 723.0, 'ytl': 467.0, 'xbr': 768.0, 'ybr': 503.0}, {'Label': 'car', 'xtl': 692.0, 'ytl': 449.0, 'xbr': 729.0, 'ybr': 479.0}, {'Label': 'truck', 'xtl': 1000.0, 'ytl': 516.0, 'xbr': 1115.0, 'ybr': 625.0}, {'Label': 'truck', 'xtl': 1276.0, 'ytl': 661.0, 'xbr': 1466.0, 'ybr': 833.0}, {'Label': 'truck', 'xtl': 795.0, 'ytl': 413.0, 'xbr': 863.0, 'ybr': 476.0}, {'Label': 'truck', 'xtl': 1718.0, 'ytl': 937.0, 'xbr': 1919.0, 'ybr': 1080.0}, {'Label': 'truck', 'xtl': 409.0, 'ytl': 343.0, 'xbr': 449.0, 'ybr': 394.0}, {'Label': 'car', 'xtl': 770.0, 'ytl': 511.0, 'xbr': 821.0, 'ybr': 551.0}]
# [{'Label': 'car', 'xtl': 763.0, 'ytl': 649.0, 'xbr': 837.0, 'ybr': 710.0}, {'Label': 'car', 'xtl': 983.0, 'ytl': 690.0, 'xbr': 1059.0, 'ybr': 748.0}, {'Label': 'car', 'xtl': 683.0, 'ytl': 720.0, 'xbr': 761.0, 'ybr': 785.0}, {'Label': 'car', 'xtl': 854.0, 'ytl': 590.0, 'xbr': 912.0, 'ybr': 633.0}, {'Label': 'car', 'xtl': 1146.0, 'ytl': 817.0, 'xbr': 1257.0, 'ybr': 905.0}, {'Label': 'truck', 'xtl': 1102.0, 'ytl': 621.0, 'xbr': 1306.0, 'ybr': 821.0}, {'Label': 'truck', 'xtl': 896.0, 'ytl': 485.0, 'xbr': 983.0, 'ybr': 570.0}, {'Label': 'truck', 'xtl': 782.0, 'ytl': 432.0, 'xbr': 862.0, 'ybr': 519.0}, {'Label': 'truck', 'xtl': 837.83, 'ytl': 415.9, 'xbr': 906.1, 'ybr': 503.34}, {'Label': 'car', 'xtl': 570.0, 'ytl': 527.0, 'xbr': 624.0, 'ybr': 580.0}, {'Label': 'car', 'xtl': 524.0, 'ytl': 472.0, 'xbr': 569.0, 'ybr': 507.0}, {'Label': 'car', 'xtl': 501.0, 'ytl': 420.0, 'xbr': 540.0, 'ybr': 453.0}, {'Label': 'car', 'xtl': 729.0, 'ytl': 473.0, 'xbr': 777.0, 'ybr': 515.0}, {'Label': 'car', 'xtl': 1070.0, 'ytl': 618.0, 'xbr': 1141.0, 'ybr': 679.0}, {'Label': 'truck', 'xtl': 1400.0, 'ytl': 838.0, 'xbr': 1709.0, 'ybr': 1079.0}, {'Label': 'truck', 'xtl': 742.0, 'ytl': 366.0, 'xbr': 802.0, 'ybr': 442.0}, {'Label': 'truck', 'xtl': 688.0, 'ytl': 343.0, 'xbr': 739.0, 'ybr': 399.0}]
# [{'Label': 'truck', 'xtl': 893.0, 'ytl': 484.0, 'xbr': 938.0, 'ybr': 530.0}, {'Label': 'bus', 'xtl': 931.0, 'ytl': 531.0, 'xbr': 1047.0, 'ybr': 644.0}, {'Label': 'bus', 'xtl': 773.0, 'ytl': 425.0, 'xbr': 846.0, 'ybr': 502.0}, {'Label': 'bus', 'xtl': 731.0, 'ytl': 398.0, 'xbr': 787.0, 'ybr': 462.0}, {'Label': 'car', 'xtl': 727.0, 'ytl': 480.0, 'xbr': 772.0, 'ybr': 516.0}, {'Label': 'car', 'xtl': 542.0, 'ytl': 485.0, 'xbr': 588.0, 'ybr': 520.0}, {'Label': 'car', 'xtl': 578.0, 'ytl': 558.0, 'xbr': 629.0, 'ybr': 604.0}, {'Label': 'car', 'xtl': 793.0, 'ytl': 540.0, 'xbr': 844.0, 'ybr': 580.0}, {'Label': 'car', 'xtl': 857.0, 'ytl': 520.0, 'xbr': 906.0, 'ybr': 557.0}, {'Label': 'car', 'xtl': 509.0, 'ytl': 439.0, 'xbr': 558.0, 'ybr': 478.0}, {'Label': 'car', 'xtl': 996.0, 'ytl': 693.0, 'xbr': 1079.0, 'ybr': 758.0}, {'Label': 'car', 'xtl': 659.0, 'ytl': 677.0, 'xbr': 734.0, 'ybr': 748.0}, {'Label': 'car', 'xtl': 825.0, 'ytl': 967.0, 'xbr': 945.0, 'ybr': 1074.0}, {'Label': 'truck', 'xtl': 625.0, 'ytl': 319.0, 'xbr': 669.0, 'ybr': 375.0}, {'Label': 'truck', 'xtl': 405.0, 'ytl': 336.0, 'xbr': 447.0, 'ybr': 389.0}, {'Label': 'car', 'xtl': 1132.0, 'ytl': 797.0, 'xbr': 1235.0, 'ybr': 877.0}, {'Label': 'car', 'xtl': 1141.0, 'ytl': 645.0, 'xbr': 1213.0, 'ybr': 695.0}, {'Label': 'truck', 'xtl': 663.27, 'ytl': 357.4, 'xbr': 709.1, 'ybr': 401.84}, {'Label': 'truck', 'xtl': 465.0, 'ytl': 362.9, 'xbr': 508.0, 'ybr': 406.0}, {'Label': 'bus', 'xtl': 459.0, 'ytl': 335.0, 'xbr': 506.0, 'ybr': 391.0}, {'Label': 'car', 'xtl': 681.72, 'ytl': 429.79, 'xbr': 717.1, 'ybr': 458.79}]
# [{'Label': 'car', 'xtl': 638.0, 'ytl': 507.0, 'xbr': 687.0, 'ybr': 547.0}, {'Label': 'car', 'xtl': 601.0, 'ytl': 583.0, 'xbr': 659.0, 'ybr': 633.0}, {'Label': 'car', 'xtl': 546.0, 'ytl': 493.0, 'xbr': 595.0, 'ybr': 531.0}, {'Label': 'car', 'xtl': 683.0, 'ytl': 686.0, 'xbr': 751.0, 'ybr': 742.0}, {'Label': 'car', 'xtl': 457.0, 'ytl': 492.0, 'xbr': 508.0, 'ybr': 529.0}, {'Label': 'car', 'xtl': 484.0, 'ytl': 582.0, 'xbr': 546.0, 'ybr': 627.0}, {'Label': 'car', 'xtl': 861.0, 'ytl': 525.0, 'xbr': 911.0, 'ybr': 566.0}, {'Label': 'truck', 'xtl': 854.0, 'ytl': 932.7, 'xbr': 1018.0, 'ybr': 1080.0}, {'Label': 'car', 'xtl': 917.26, 'ytl': 825.1, 'xbr': 1000.8, 'ybr': 908.85}, {'Label': 'car', 'xtl': 791.0, 'ytl': 475.0, 'xbr': 842.0, 'ybr': 513.0}, {'Label': 'bus', 'xtl': 734.0, 'ytl': 401.0, 'xbr': 802.0, 'ybr': 472.0}, {'Label': 'bus', 'xtl': 712.0, 'ytl': 712.0, 'xbr': 870.0, 'ybr': 913.0}, {'Label': 'car', 'xtl': 498.0, 'ytl': 425.0, 'xbr': 536.0, 'ybr': 457.0}, {'Label': 'car', 'xtl': 654.0, 'ytl': 406.0, 'xbr': 689.0, 'ybr': 438.0}, {'Label': 'truck', 'xtl': 858.0, 'ytl': 440.0, 'xbr': 938.0, 'ybr': 528.0}, {'Label': 'truck', 'xtl': 512.0, 'ytl': 596.0, 'xbr': 643.0, 'ybr': 774.0}, {'Label': 'truck', 'xtl': 1290.0, 'ytl': 731.0, 'xbr': 1393.0, 'ybr': 812.0}, {'Label': 'car', 'xtl': 1129.0, 'ytl': 817.0, 'xbr': 1231.0, 'ybr': 887.0}, {'Label': 'car', 'xtl': 904.0, 'ytl': 629.0, 'xbr': 972.0, 'ybr': 679.0}, {'Label': 'car', 'xtl': 1008.0, 'ytl': 573.0, 'xbr': 1067.0, 'ybr': 617.0}]
# [{'Label': 'truck', 'xtl': 1259.0, 'ytl': 654.0, 'xbr': 1450.0, 'ybr': 820.0}, {'Label': 'car', 'xtl': 769.0, 'ytl': 673.0, 'xbr': 842.0, 'ybr': 732.0}, {'Label': 'car', 'xtl': 1080.0, 'ytl': 692.0, 'xbr': 1161.0, 'ybr': 749.0}, {'Label': 'car', 'xtl': 660.0, 'ytl': 544.0, 'xbr': 716.0, 'ybr': 587.0}, {'Label': 'car', 'xtl': 694.0, 'ytl': 716.0, 'xbr': 788.0, 'ybr': 809.0}, {'Label': 'car', 'xtl': 878.0, 'ytl': 787.0, 'xbr': 970.0, 'ybr': 870.0}, {'Label': 'car', 'xtl': 579.0, 'ytl': 547.0, 'xbr': 629.0, 'ybr': 587.0}, {'Label': 'car', 'xtl': 524.0, 'ytl': 459.0, 'xbr': 565.0, 'ybr': 494.0}, {'Label': 'car', 'xtl': 518.0, 'ytl': 437.0, 'xbr': 560.0, 'ybr': 470.0}, {'Label': 'truck', 'xtl': 931.0, 'ytl': 465.0, 'xbr': 1043.0, 'ybr': 584.0}]
# [{'Label': 'truck', 'xtl': 684.0, 'ytl': 341.0, 'xbr': 731.0, 'ybr': 390.0}, {'Label': 'truck', 'xtl': 1045.0, 'ytl': 640.0, 'xbr': 1121.0, 'ybr': 715.0}, {'Label': 'truck', 'xtl': 1260.0, 'ytl': 655.0, 'xbr': 1447.0, 'ybr': 827.0}, {'Label': 'bus', 'xtl': 612.0, 'ytl': 539.0, 'xbr': 721.0, 'ybr': 668.0}, {'Label': 'car', 'xtl': 494.0, 'ytl': 593.0, 'xbr': 557.0, 'ybr': 650.0}, {'Label': 'car', 'xtl': 859.0, 'ytl': 772.0, 'xbr': 951.0, 'ybr': 845.0}, {'Label': 'car', 'xtl': 1400.0, 'ytl': 922.0, 'xbr': 1520.0, 'ybr': 1005.0}, {'Label': 'car', 'xtl': 1022.0, 'ytl': 723.0, 'xbr': 1105.0, 'ybr': 791.0}, {'Label': 'car', 'xtl': 464.0, 'ytl': 485.0, 'xbr': 507.0, 'ybr': 523.0}, {'Label': 'car', 'xtl': 652.0, 'ytl': 669.0, 'xbr': 736.0, 'ybr': 750.0}, {'Label': 'car', 'xtl': 944.0, 'ytl': 588.0, 'xbr': 998.0, 'ybr': 633.0}, {'Label': 'car', 'xtl': 699.0, 'ytl': 454.0, 'xbr': 741.0, 'ybr': 488.0}, {'Label': 'car', 'xtl': 645.0, 'ytl': 521.0, 'xbr': 695.0, 'ybr': 564.0}, {'Label': 'truck', 'xtl': 964.0, 'ytl': 489.0, 'xbr': 1081.0, 'ybr': 603.0}, {'Label': 'car', 'xtl': 913.25, 'ytl': 1049.48, 'xbr': 1019.88, 'ybr': 1080.0}]
# [{'Label': 'car', 'xtl': 477.0, 'ytl': 535.0, 'xbr': 536.0, 'ybr': 579.0}, {'Label': 'car', 'xtl': 761.0, 'ytl': 468.0, 'xbr': 804.0, 'ybr': 501.0}, {'Label': 'car', 'xtl': 937.0, 'ytl': 582.0, 'xbr': 997.0, 'ybr': 626.0}, {'Label': 'truck', 'xtl': 558.0, 'ytl': 487.0, 'xbr': 618.0, 'ybr': 556.0}, {'Label': 'car', 'xtl': 892.0, 'ytl': 617.0, 'xbr': 958.0, 'ybr': 667.0}, {'Label': 'truck', 'xtl': 675.0, 'ytl': 335.0, 'xbr': 717.0, 'ybr': 384.0}, {'Label': 'truck', 'xtl': 631.0, 'ytl': 309.0, 'xbr': 675.0, 'ybr': 361.0}, {'Label': 'car', 'xtl': 688.0, 'ytl': 400.0, 'xbr': 723.0, 'ybr': 431.0}, {'Label': 'car', 'xtl': 1397.0, 'ytl': 1035.0, 'xbr': 1534.0, 'ybr': 1080.0}, {'Label': 'car', 'xtl': 878.0, 'ytl': 815.0, 'xbr': 971.0, 'ybr': 890.0}, {'Label': 'truck', 'xtl': 735.0, 'ytl': 370.0, 'xbr': 786.0, 'ybr': 428.0}, {'Label': 'car', 'xtl': 656.07, 'ytl': 419.07, 'xbr': 690.07, 'ybr': 449.07}, {'Label': 'car', 'xtl': 640.0, 'ytl': 515.0, 'xbr': 692.0, 'ybr': 556.0}]
# [{'Label': 'car', 'xtl': 551.0, 'ytl': 502.0, 'xbr': 601.0, 'ybr': 543.0}, {'Label': 'car', 'xtl': 584.0, 'ytl': 455.0, 'xbr': 626.0, 'ybr': 485.0}, {'Label': 'car', 'xtl': 462.0, 'ytl': 501.0, 'xbr': 503.0, 'ybr': 535.0}, {'Label': 'car', 'xtl': 816.0, 'ytl': 491.0, 'xbr': 859.0, 'ybr': 527.0}, {'Label': 'car', 'xtl': 870.0, 'ytl': 1010.0, 'xbr': 1012.0, 'ybr': 1080.0}, {'Label': 'car', 'xtl': 888.0, 'ytl': 793.0, 'xbr': 986.0, 'ybr': 883.0}, {'Label': 'car', 'xtl': 792.0, 'ytl': 535.0, 'xbr': 846.0, 'ybr': 575.0}, {'Label': 'car', 'xtl': 646.0, 'ytl': 657.0, 'xbr': 708.0, 'ybr': 711.0}, {'Label': 'car', 'xtl': 753.0, 'ytl': 839.0, 'xbr': 852.0, 'ybr': 927.0}, {'Label': 'car', 'xtl': 1334.0, 'ytl': 990.0, 'xbr': 1471.0, 'ybr': 1076.0}, {'Label': 'car', 'xtl': 1010.0, 'ytl': 702.0, 'xbr': 1097.0, 'ybr': 773.0}, {'Label': 'truck', 'xtl': 772.0, 'ytl': 378.0, 'xbr': 845.0, 'ybr': 461.0}, {'Label': 'truck', 'xtl': 1683.0, 'ytl': 935.0, 'xbr': 1920.0, 'ybr': 1080.0}]
# [{'Label': 'car', 'xtl': 434.0, 'ytl': 434.0, 'xbr': 474.0, 'ybr': 468.0}, {'Label': 'car', 'xtl': 678.0, 'ytl': 431.0, 'xbr': 715.0, 'ybr': 463.0}, {'Label': 'bus', 'xtl': 695.0, 'ytl': 380.0, 'xbr': 744.0, 'ybr': 437.0}, {'Label': 'car', 'xtl': 851.0, 'ytl': 967.0, 'xbr': 977.0, 'ybr': 1077.0}, {'Label': 'truck', 'xtl': 748.99, 'ytl': 384.77, 'xbr': 795.59, 'ybr': 432.77}, {'Label': 'truck', 'xtl': 952.0, 'ytl': 471.0, 'xbr': 1062.0, 'ybr': 581.0}, {'Label': 'car', 'xtl': 1355.0, 'ytl': 1029.0, 'xbr': 1499.0, 'ybr': 1080.0}, {'Label': 'car', 'xtl': 986.0, 'ytl': 684.0, 'xbr': 1065.0, 'ybr': 748.0}]
# [{'Label': 'car', 'xtl': 559.0, 'ytl': 512.0, 'xbr': 615.0, 'ybr': 559.0}, {'Label': 'car', 'xtl': 771.0, 'ytl': 516.0, 'xbr': 819.0, 'ybr': 553.0}, {'Label': 'car', 'xtl': 869.0, 'ytl': 532.0, 'xbr': 916.0, 'ybr': 569.0}, {'Label': 'truck', 'xtl': 452.0, 'ytl': 480.0, 'xbr': 523.0, 'ybr': 566.0}, {'Label': 'truck', 'xtl': 456.0, 'ytl': 411.0, 'xbr': 515.0, 'ybr': 487.0}, {'Label': 'truck', 'xtl': 1775.0, 'ytl': 949.0, 'xbr': 1919.0, 'ybr': 1080.0}, {'Label': 'car', 'xtl': 730.0, 'ytl': 419.0, 'xbr': 773.0, 'ybr': 454.0}, {'Label': 'truck', 'xtl': 680.0, 'ytl': 364.0, 'xbr': 735.0, 'ybr': 421.0}, {'Label': 'truck', 'xtl': 619.0, 'ytl': 301.0, 'xbr': 659.0, 'ybr': 346.0}, {'Label': 'truck', 'xtl': 832.0, 'ytl': 422.0, 'xbr': 911.0, 'ybr': 503.0}, {'Label': 'car', 'xtl': 510.0, 'ytl': 424.0, 'xbr': 548.0, 'ybr': 456.0}, {'Label': 'car', 'xtl': 535.0, 'ytl': 460.0, 'xbr': 577.0, 'ybr': 492.0}, {'Label': 'car', 'xtl': 1070.0, 'ytl': 669.0, 'xbr': 1147.0, 'ybr': 730.0}, {'Label': 'car', 'xtl': 878.0, 'ytl': 600.0, 'xbr': 944.0, 'ybr': 651.0}, {'Label': 'car', 'xtl': 807.0, 'ytl': 899.0, 'xbr': 925.0, 'ybr': 1024.0}]
# [{'Label': 'truck', 'xtl': 762.05, 'ytl': 382.1, 'xbr': 817.05, 'ybr': 445.1}, {'Label': 'car', 'xtl': 673.0, 'ytl': 727.0, 'xbr': 755.0, 'ybr': 796.0}, {'Label': 'car', 'xtl': 1105.0, 'ytl': 788.0, 'xbr': 1200.0, 'ybr': 863.0}, {'Label': 'car', 'xtl': 1055.0, 'ytl': 664.0, 'xbr': 1140.0, 'ybr': 727.0}, {'Label': 'car', 'xtl': 597.0, 'ytl': 589.0, 'xbr': 658.0, 'ybr': 646.0}, {'Label': 'car', 'xtl': 564.0, 'ytl': 524.0, 'xbr': 618.0, 'ybr': 572.0}, {'Label': 'car', 'xtl': 622.0, 'ytl': 817.0, 'xbr': 699.0, 'ybr': 892.0}, {'Label': 'car', 'xtl': 685.0, 'ytl': 440.0, 'xbr': 724.0, 'ybr': 470.0}, {'Label': 'car', 'xtl': 582.0, 'ytl': 455.4, 'xbr': 630.0, 'ybr': 489.0}, {'Label': 'truck', 'xtl': 853.0, 'ytl': 430.0, 'xbr': 940.0, 'ybr': 516.0}, {'Label': 'truck', 'xtl': 1021.0, 'ytl': 511.0, 'xbr': 1158.0, 'ybr': 650.0}, {'Label': 'car', 'xtl': 583.84, 'ytl': 434.87, 'xbr': 624.84, 'ybr': 464.87}]
# [{'Label': 'car', 'xtl': 601.0, 'ytl': 603.0, 'xbr': 661.0, 'ybr': 657.0}, {'Label': 'truck', 'xtl': 610.0, 'ytl': 298.0, 'xbr': 650.0, 'ybr': 339.0}, {'Label': 'truck', 'xtl': 397.0, 'ytl': 301.0, 'xbr': 435.0, 'ybr': 356.0}, {'Label': 'truck', 'xtl': 822.0, 'ytl': 426.0, 'xbr': 874.0, 'ybr': 484.0}, {'Label': 'car', 'xtl': 776.0, 'ytl': 468.0, 'xbr': 822.0, 'ybr': 503.0}, {'Label': 'car', 'xtl': 904.0, 'ytl': 1037.0, 'xbr': 1011.0, 'ybr': 1080.0}, {'Label': 'car', 'xtl': 565.0, 'ytl': 422.0, 'xbr': 599.0, 'ybr': 451.0}, {'Label': 'car', 'xtl': 494.0, 'ytl': 401.0, 'xbr': 531.0, 'ybr': 435.0}, {'Label': 'car', 'xtl': 443.0, 'ytl': 431.0, 'xbr': 482.8, 'ybr': 464.0}, {'Label': 'truck', 'xtl': 646.42, 'ytl': 310.3, 'xbr': 697.4, 'ybr': 368.0}, {'Label': 'car', 'xtl': 1005.0, 'ytl': 629.0, 'xbr': 1075.0, 'ybr': 676.0}, {'Label': 'car', 'xtl': 523.0, 'ytl': 454.0, 'xbr': 565.0, 'ybr': 488.0}, {'Label': 'car', 'xtl': 723.0, 'ytl': 631.0, 'xbr': 788.0, 'ybr': 681.0}, {'Label': 'car', 'xtl': 1286.0, 'ytl': 959.0, 'xbr': 1413.0, 'ybr': 1041.0}, {'Label': 'car', 'xtl': 549.0, 'ytl': 489.0, 'xbr': 597.0, 'ybr': 527.0}]
# [{'Label': 'car', 'xtl': 541.66, 'ytl': 391.43, 'xbr': 573.81, 'ybr': 422.6}, {'Label': 'truck', 'xtl': 846.0, 'ytl': 456.0, 'xbr': 895.0, 'ybr': 505.0}, {'Label': 'car', 'xtl': 723.0, 'ytl': 472.0, 'xbr': 766.0, 'ybr': 506.0}, {'Label': 'car', 'xtl': 788.0, 'ytl': 520.0, 'xbr': 844.0, 'ybr': 563.0}, {'Label': 'bus', 'xtl': 607.0, 'ytl': 452.0, 'xbr': 679.0, 'ybr': 539.0}, {'Label': 'truck', 'xtl': 1215.0, 'ytl': 640.0, 'xbr': 1365.0, 'ybr': 786.0}, {'Label': 'car', 'xtl': 804.0, 'ytl': 478.0, 'xbr': 849.0, 'ybr': 512.0}, {'Label': 'truck', 'xtl': 474.0, 'ytl': 503.0, 'xbr': 567.0, 'ybr': 635.0}, {'Label': 'car', 'xtl': 524.0, 'ytl': 482.0, 'xbr': 579.0, 'ybr': 525.0}, {'Label': 'car', 'xtl': 566.0, 'ytl': 529.0, 'xbr': 621.0, 'ybr': 585.0}, {'Label': 'car', 'xtl': 677.0, 'ytl': 432.0, 'xbr': 712.0, 'ybr': 461.0}, {'Label': 'car', 'xtl': 482.0, 'ytl': 398.0, 'xbr': 516.0, 'ybr': 425.0}]
# [{'Label': 'truck', 'xtl': 406.0, 'ytl': 327.0, 'xbr': 450.0, 'ybr': 399.0}, {'Label': 'car', 'xtl': 664.0, 'ytl': 557.0, 'xbr': 718.0, 'ybr': 598.0}, {'Label': 'car', 'xtl': 801.0, 'ytl': 707.0, 'xbr': 877.0, 'ybr': 771.0}, {'Label': 'car', 'xtl': 711.0, 'ytl': 753.0, 'xbr': 800.0, 'ybr': 837.0}, {'Label': 'car', 'xtl': 887.0, 'ytl': 607.0, 'xbr': 951.0, 'ybr': 656.0}, {'Label': 'car', 'xtl': 835.0, 'ytl': 504.0, 'xbr': 887.0, 'ybr': 542.0}, {'Label': 'car', 'xtl': 610.0, 'ytl': 620.0, 'xbr': 680.0, 'ybr': 670.0}, {'Label': 'car', 'xtl': 627.0, 'ytl': 506.0, 'xbr': 678.0, 'ybr': 543.0}, {'Label': 'car', 'xtl': 581.0, 'ytl': 455.0, 'xbr': 622.0, 'ybr': 489.0}, {'Label': 'truck', 'xtl': 869.0, 'ytl': 464.0, 'xbr': 915.0, 'ybr': 514.0}, {'Label': 'truck', 'xtl': 750.0, 'ytl': 390.0, 'xbr': 806.0, 'ybr': 446.0}, {'Label': 'truck', 'xtl': 684.0, 'ytl': 341.0, 'xbr': 724.0, 'ybr': 391.0}, {'Label': 'truck', 'xtl': 462.0, 'ytl': 348.0, 'xbr': 499.0, 'ybr': 392.0}]
# [{'Label': 'truck', 'xtl': 739.0, 'ytl': 807.0, 'xbr': 907.0, 'ybr': 977.0}, {'Label': 'truck', 'xtl': 489.0, 'ytl': 538.0, 'xbr': 591.0, 'ybr': 682.0}, {'Label': 'truck', 'xtl': 525.0, 'ytl': 632.0, 'xbr': 661.0, 'ybr': 829.0}, {'Label': 'truck', 'xtl': 985.0, 'ytl': 504.0, 'xbr': 1114.0, 'ybr': 626.0}, {'Label': 'car', 'xtl': 552.0, 'ytl': 519.0, 'xbr': 600.0, 'ybr': 562.0}, {'Label': 'car', 'xtl': 698.0, 'ytl': 570.0, 'xbr': 755.0, 'ybr': 619.0}, {'Label': 'car', 'xtl': 1105.0, 'ytl': 700.0, 'xbr': 1186.0, 'ybr': 762.0}, {'Label': 'car', 'xtl': 916.06, 'ytl': 839.04, 'xbr': 1007.25, 'ybr': 921.81}, {'Label': 'bus', 'xtl': 602.0, 'ytl': 536.0, 'xbr': 699.0, 'ybr': 662.0}, {'Label': 'car', 'xtl': 583.0, 'ytl': 454.0, 'xbr': 627.0, 'ybr': 486.0}, {'Label': 'car', 'xtl': 636.0, 'ytl': 651.0, 'xbr': 711.0, 'ybr': 710.0}, {'Label': 'car', 'xtl': 497.0, 'ytl': 425.0, 'xbr': 536.0, 'ybr': 454.0}, {'Label': 'car', 'xtl': 628.0, 'ytl': 507.0, 'xbr': 682.0, 'ybr': 549.0}, {'Label': 'truck', 'xtl': 425.0, 'ytl': 410.0, 'xbr': 471.0, 'ybr': 460.0}, {'Label': 'truck', 'xtl': 690.0, 'ytl': 371.0, 'xbr': 755.0, 'ybr': 436.0}]
# [{'Label': 'car', 'xtl': 871.0, 'ytl': 604.0, 'xbr': 935.0, 'ybr': 651.0}, {'Label': 'car', 'xtl': 784.0, 'ytl': 693.0, 'xbr': 865.0, 'ybr': 758.0}, {'Label': 'car', 'xtl': 625.0, 'ytl': 618.0, 'xbr': 697.0, 'ybr': 688.0}, {'Label': 'car', 'xtl': 583.0, 'ytl': 558.0, 'xbr': 642.0, 'ybr': 606.0}, {'Label': 'car', 'xtl': 497.0, 'ytl': 583.0, 'xbr': 556.0, 'ybr': 635.0}, {'Label': 'car', 'xtl': 687.0, 'ytl': 727.0, 'xbr': 766.0, 'ybr': 794.0}, {'Label': 'car', 'xtl': 593.0, 'ytl': 459.0, 'xbr': 638.0, 'ybr': 495.0}, {'Label': 'car', 'xtl': 482.0, 'ytl': 518.0, 'xbr': 536.0, 'ybr': 569.0}, {'Label': 'car', 'xtl': 1379.0, 'ytl': 1028.0, 'xbr': 1516.0, 'ybr': 1080.0}, {'Label': 'truck', 'xtl': 1520.0, 'ytl': 804.0, 'xbr': 1803.0, 'ybr': 1044.0}, {'Label': 'truck', 'xtl': 404.0, 'ytl': 323.0, 'xbr': 442.0, 'ybr': 379.0}, {'Label': 'truck', 'xtl': 541.0, 'ytl': 462.0, 'xbr': 592.0, 'ybr': 530.0}, {'Label': 'truck', 'xtl': 1190.0, 'ytl': 759.0, 'xbr': 1295.0, 'ybr': 858.0}, {'Label': 'truck', 'xtl': 1307.0, 'ytl': 669.0, 'xbr': 1563.0, 'ybr': 892.0}, {'Label': 'truck', 'xtl': 1113.0, 'ytl': 566.0, 'xbr': 1206.0, 'ybr': 678.0}, {'Label': 'truck', 'xtl': 627.0, 'ytl': 308.0, 'xbr': 670.0, 'ybr': 356.0}, {'Label': 'truck', 'xtl': 834.0, 'ytl': 454.0, 'xbr': 941.8, 'ybr': 569.0}, {'Label': 'truck', 'xtl': 858.54, 'ytl': 433.59, 'xbr': 944.12, 'ybr': 519.17}, {'Label': 'car', 'xtl': 946.85, 'ytl': 889.38, 'xbr': 1070.3, 'ybr': 982.6}, {'Label': 'car', 'xtl': 557.0, 'ytl': 411.0, 'xbr': 592.0, 'ybr': 441.0}, {'Label': 'car', 'xtl': 525.0, 'ytl': 450.0, 'xbr': 564.0, 'ybr': 486.0}, {'Label': 'car', 'xtl': 513.0, 'ytl': 433.0, 'xbr': 553.0, 'ybr': 469.0}]
# [{'Label': 'car', 'xtl': 837.0, 'ytl': 566.0, 'xbr': 895.0, 'ybr': 608.0}, {'Label': 'truck', 'xtl': 423.0, 'ytl': 362.0, 'xbr': 470.0, 'ybr': 418.0}, {'Label': 'car', 'xtl': 439.0, 'ytl': 443.0, 'xbr': 480.0, 'ybr': 479.0}, {'Label': 'truck', 'xtl': 725.91, 'ytl': 393.61, 'xbr': 788.3, 'ybr': 451.61}, {'Label': 'car', 'xtl': 1343.0, 'ytl': 1026.0, 'xbr': 1490.0, 'ybr': 1080.0}, {'Label': 'car', 'xtl': 598.0, 'ytl': 476.0, 'xbr': 646.0, 'ybr': 514.0}, {'Label': 'car', 'xtl': 821.0, 'ytl': 822.0, 'xbr': 923.0, 'ybr': 913.0}, {'Label': 'car', 'xtl': 944.0, 'ytl': 538.0, 'xbr': 1006.0, 'ybr': 585.0}, {'Label': 'car', 'xtl': 1040.0, 'ytl': 999.0, 'xbr': 1175.0, 'ybr': 1080.0}, {'Label': 'car', 'xtl': 1128.0, 'ytl': 807.0, 'xbr': 1240.0, 'ybr': 888.0}, {'Label': 'truck', 'xtl': 504.0, 'ytl': 572.0, 'xbr': 611.0, 'ybr': 722.0}, {'Label': 'car', 'xtl': 575.0, 'ytl': 442.0, 'xbr': 614.0, 'ybr': 473.0}, {'Label': 'car', 'xtl': 671.0, 'ytl': 559.0, 'xbr': 729.0, 'ybr': 605.0}, {'Label': 'car', 'xtl': 626.0, 'ytl': 996.0, 'xbr': 752.0, 'ybr': 1080.0}, {'Label': 'car', 'xtl': 557.0, 'ytl': 520.0, 'xbr': 612.0, 'ybr': 564.0}, {'Label': 'bus', 'xtl': 735.0, 'ytl': 445.0, 'xbr': 814.0, 'ybr': 534.0}, {'Label': 'bus', 'xtl': 640.0, 'ytl': 376.0, 'xbr': 691.0, 'ybr': 438.0}, {'Label': 'truck', 'xtl': 869.0, 'ytl': 432.0, 'xbr': 959.0, 'ybr': 538.0}, {'Label': 'truck', 'xtl': 1094.0, 'ytl': 671.0, 'xbr': 1182.0, 'ybr': 752.0}, {'Label': 'truck', 'xtl': 1658.0, 'ytl': 971.0, 'xbr': 1900.0, 'ybr': 1080.0}, {'Label': 'truck', 'xtl': 716.31, 'ytl': 346.7, 'xbr': 777.6, 'ybr': 412.15}, {'Label': 'truck', 'xtl': 745.34, 'ytl': 369.07, 'xbr': 798.0, 'ybr': 427.8}, {'Label': 'truck', 'xtl': 813.63, 'ytl': 400.43, 'xbr': 885.63, 'ybr': 477.43}]
# [{'Label': 'car', 'xtl': 1110.0, 'ytl': 812.0, 'xbr': 1211.0, 'ybr': 890.0}, {'Label': 'car', 'xtl': 659.84, 'ytl': 415.98, 'xbr': 694.91, 'ybr': 447.15}, {'Label': 'bus', 'xtl': 812.0, 'ytl': 968.0, 'xbr': 1053.0, 'ybr': 1080.0}, {'Label': 'truck', 'xtl': 1515.0, 'ytl': 850.8, 'xbr': 1646.68, 'ybr': 969.59}, {'Label': 'truck', 'xtl': 850.0, 'ytl': 429.0, 'xbr': 936.0, 'ybr': 517.0}, {'Label': 'truck', 'xtl': 975.0, 'ytl': 501.0, 'xbr': 1108.0, 'ybr': 650.0}, {'Label': 'truck', 'xtl': 1260.0, 'ytl': 719.0, 'xbr': 1565.0, 'ybr': 985.0}, {'Label': 'truck', 'xtl': 785.0, 'ytl': 387.0, 'xbr': 856.0, 'ybr': 468.0}, {'Label': 'truck', 'xtl': 569.0, 'ytl': 740.0, 'xbr': 696.0, 'ybr': 892.0}, {'Label': 'truck', 'xtl': 705.0, 'ytl': 373.0, 'xbr': 771.0, 'ybr': 455.0}, {'Label': 'truck', 'xtl': 827.0, 'ytl': 853.0, 'xbr': 945.0, 'ybr': 1003.0}, {'Label': 'truck', 'xtl': 1005.0, 'ytl': 556.0, 'xbr': 1162.0, 'ybr': 716.0}, {'Label': 'truck', 'xtl': 412.0, 'ytl': 354.0, 'xbr': 464.0, 'ybr': 432.0}, {'Label': 'truck', 'xtl': 964.04, 'ytl': 577.88, 'xbr': 1028.34, 'ybr': 642.18}, {'Label': 'car', 'xtl': 708.0, 'ytl': 583.0, 'xbr': 772.0, 'ybr': 636.0}, {'Label': 'car', 'xtl': 651.0, 'ytl': 529.0, 'xbr': 700.0, 'ybr': 568.0}, {'Label': 'car', 'xtl': 1274.0, 'ytl': 936.0, 'xbr': 1417.0, 'ybr': 1049.0}, {'Label': 'car', 'xtl': 723.0, 'ytl': 767.0, 'xbr': 822.0, 'ybr': 857.0}, {'Label': 'car', 'xtl': 556.0, 'ytl': 529.0, 'xbr': 609.0, 'ybr': 570.0}, {'Label': 'car', 'xtl': 854.0, 'ytl': 581.0, 'xbr': 918.0, 'ybr': 630.0}, {'Label': 'car', 'xtl': 784.0, 'ytl': 472.0, 'xbr': 827.0, 'ybr': 505.0}, {'Label': 'car', 'xtl': 837.0, 'ytl': 499.0, 'xbr': 885.0, 'ybr': 543.0}, {'Label': 'car', 'xtl': 509.0, 'ytl': 441.0, 'xbr': 550.0, 'ybr': 471.0}, {'Label': 'car', 'xtl': 557.0, 'ytl': 418.0, 'xbr': 594.0, 'ybr': 447.0}, {'Label': 'car', 'xtl': 589.0, 'ytl': 456.0, 'xbr': 632.0, 'ybr': 488.0}, {'Label': 'car', 'xtl': 698.0, 'ytl': 454.0, 'xbr': 736.0, 'ybr': 486.0}]
# [{'Label': 'car', 'xtl': 799.0, 'ytl': 525.0, 'xbr': 848.0, 'ybr': 563.0}, {'Label': 'car', 'xtl': 770.0, 'ytl': 651.0, 'xbr': 843.0, 'ybr': 719.0}, {'Label': 'truck', 'xtl': 417.0, 'ytl': 358.0, 'xbr': 462.0, 'ybr': 409.0}, {'Label': 'truck', 'xtl': 664.0, 'ytl': 350.0, 'xbr': 716.0, 'ybr': 423.0}, {'Label': 'truck', 'xtl': 1148.0, 'ytl': 716.0, 'xbr': 1219.0, 'ybr': 779.0}, {'Label': 'truck', 'xtl': 614.0, 'ytl': 315.0, 'xbr': 661.0, 'ybr': 374.0}, {'Label': 'car', 'xtl': 680.0, 'ytl': 569.0, 'xbr': 735.0, 'ybr': 614.0}, {'Label': 'car', 'xtl': 944.0, 'ytl': 659.0, 'xbr': 1016.0, 'ybr': 716.0}, {'Label': 'truck', 'xtl': 903.0, 'ytl': 534.0, 'xbr': 961.0, 'ybr': 588.0}, {'Label': 'car', 'xtl': 1149.0, 'ytl': 830.0, 'xbr': 1256.0, 'ybr': 904.0}, {'Label': 'truck', 'xtl': 1085.0, 'ytl': 550.0, 'xbr': 1246.0, 'ybr': 690.0}, {'Label': 'truck', 'xtl': 585.0, 'ytl': 780.0, 'xbr': 785.0, 'ybr': 1079.0}, {'Label': 'truck', 'xtl': 462.0, 'ytl': 483.0, 'xbr': 555.0, 'ybr': 610.0}, {'Label': 'truck', 'xtl': 678.0, 'ytl': 667.0, 'xbr': 791.0, 'ybr': 789.0}, {'Label': 'truck', 'xtl': 528.0, 'ytl': 633.0, 'xbr': 642.0, 'ybr': 805.0}, {'Label': 'car', 'xtl': 704.0, 'ytl': 451.0, 'xbr': 747.0, 'ybr': 485.0}, {'Label': 'car', 'xtl': 732.0, 'ytl': 476.0, 'xbr': 775.0, 'ybr': 509.0}]
# [{'Label': 'car', 'xtl': 659.05, 'ytl': 410.13, 'xbr': 687.24, 'ybr': 438.88}, {'Label': 'truck', 'xtl': 402.0, 'ytl': 325.0, 'xbr': 439.0, 'ybr': 378.0}, {'Label': 'truck', 'xtl': 847.0, 'ytl': 472.0, 'xbr': 895.0, 'ybr': 519.0}, {'Label': 'truck', 'xtl': 1754.0, 'ytl': 924.0, 'xbr': 1920.0, 'ybr': 1080.0}, {'Label': 'truck', 'xtl': 817.0, 'ytl': 429.0, 'xbr': 878.0, 'ybr': 487.0}, {'Label': 'car', 'xtl': 744.0, 'ytl': 477.0, 'xbr': 782.0, 'ybr': 510.0}, {'Label': 'car', 'xtl': 684.0, 'ytl': 435.0, 'xbr': 719.0, 'ybr': 466.0}, {'Label': 'car', 'xtl': 783.0, 'ytl': 464.0, 'xbr': 821.0, 'ybr': 496.0}, {'Label': 'car', 'xtl': 711.0, 'ytl': 463.0, 'xbr': 749.0, 'ybr': 496.0}, {'Label': 'car', 'xtl': 510.0, 'ytl': 429.0, 'xbr': 553.0, 'ybr': 465.0}, {'Label': 'car', 'xtl': 757.0, 'ytl': 503.0, 'xbr': 802.0, 'ybr': 539.0}, {'Label': 'car', 'xtl': 664.0, 'ytl': 537.0, 'xbr': 718.0, 'ybr': 581.0}, {'Label': 'car', 'xtl': 577.0, 'ytl': 543.0, 'xbr': 633.0, 'ybr': 592.0}, {'Label': 'car', 'xtl': 700.0, 'ytl': 651.0, 'xbr': 771.0, 'ybr': 705.0}, {'Label': 'truck', 'xtl': 657.92, 'ytl': 321.61, 'xbr': 699.08, 'ybr': 370.66}, {'Label': 'truck', 'xtl': 701.33, 'ytl': 394.9, 'xbr': 745.87, 'ybr': 436.63}, {'Label': 'truck', 'xtl': 723.89, 'ytl': 416.89, 'xbr': 758.84, 'ybr': 451.28}, {'Label': 'truck', 'xtl': 659.25, 'ytl': 912.95, 'xbr': 894.05, 'ybr': 1078.57}]
# [{'Label': 'truck', 'xtl': 394.0, 'ytl': 295.0, 'xbr': 430.0, 'ybr': 340.0}, {'Label': 'car', 'xtl': 1025.0, 'ytl': 948.0, 'xbr': 1148.0, 'ybr': 1052.0}, {'Label': 'car', 'xtl': 554.0, 'ytl': 514.0, 'xbr': 612.0, 'ybr': 562.0}, {'Label': 'car', 'xtl': 759.0, 'ytl': 662.0, 'xbr': 834.0, 'ybr': 718.0}, {'Label': 'car', 'xtl': 892.0, 'ytl': 788.0, 'xbr': 986.0, 'ybr': 864.0}, {'Label': 'car', 'xtl': 676.0, 'ytl': 557.0, 'xbr': 741.0, 'ybr': 609.0}, {'Label': 'car', 'xtl': 601.0, 'ytl': 585.0, 'xbr': 657.0, 'ybr': 635.0}, {'Label': 'car', 'xtl': 529.0, 'ytl': 471.0, 'xbr': 574.0, 'ybr': 508.0}, {'Label': 'car', 'xtl': 494.0, 'ytl': 413.0, 'xbr': 530.0, 'ybr': 442.0}, {'Label': 'car', 'xtl': 518.0, 'ytl': 438.0, 'xbr': 560.0, 'ybr': 476.0}, {'Label': 'car', 'xtl': 565.0, 'ytl': 426.0, 'xbr': 601.0, 'ybr': 456.0}, {'Label': 'car', 'xtl': 710.0, 'ytl': 736.0, 'xbr': 794.0, 'ybr': 812.0}, {'Label': 'truck', 'xtl': 511.0, 'ytl': 602.0, 'xbr': 622.0, 'ybr': 770.0}, {'Label': 'truck', 'xtl': 889.0, 'ytl': 443.0, 'xbr': 992.0, 'ybr': 552.0}, {'Label': 'truck', 'xtl': 435.0, 'ytl': 400.0, 'xbr': 490.0, 'ybr': 475.0}, {'Label': 'truck', 'xtl': 1193.0, 'ytl': 735.0, 'xbr': 1292.0, 'ybr': 827.0}, {'Label': 'truck', 'xtl': 747.0, 'ytl': 370.0, 'xbr': 808.0, 'ybr': 441.0}]
# [{'Label': 'car', 'xtl': 953.0, 'ytl': 676.0, 'xbr': 1021.0, 'ybr': 728.0}, {'Label': 'truck', 'xtl': 1492.0, 'ytl': 938.0, 'xbr': 1661.0, 'ybr': 1078.0}, {'Label': 'truck', 'xtl': 743.0, 'ytl': 423.0, 'xbr': 784.0, 'ybr': 473.0}, {'Label': 'truck', 'xtl': 423.0, 'ytl': 391.0, 'xbr': 478.0, 'ybr': 451.0}, {'Label': 'truck', 'xtl': 692.0, 'ytl': 373.0, 'xbr': 760.0, 'ybr': 449.0}, {'Label': 'truck', 'xtl': 855.0, 'ytl': 437.0, 'xbr': 931.0, 'ybr': 515.0}, {'Label': 'truck', 'xtl': 765.0, 'ytl': 426.0, 'xbr': 826.0, 'ybr': 494.0}, {'Label': 'truck', 'xtl': 1275.0, 'ytl': 787.0, 'xbr': 1380.0, 'ybr': 882.0}, {'Label': 'truck', 'xtl': 883.0, 'ytl': 489.0, 'xbr': 963.0, 'ybr': 591.0}, {'Label': 'truck', 'xtl': 1088.0, 'ytl': 566.0, 'xbr': 1205.0, 'ybr': 680.0}, {'Label': 'truck', 'xtl': 484.0, 'ytl': 543.0, 'xbr': 580.0, 'ybr': 674.0}, {'Label': 'bus', 'xtl': 607.0, 'ytl': 546.0, 'xbr': 705.0, 'ybr': 685.0}, {'Label': 'truck', 'xtl': 620.29, 'ytl': 297.8, 'xbr': 665.4, 'ybr': 351.96}, {'Label': 'bus', 'xtl': 456.0, 'ytl': 332.0, 'xbr': 490.0, 'ybr': 373.0}, {'Label': 'car', 'xtl': 965.0, 'ytl': 611.0, 'xbr': 1025.0, 'ybr': 655.0}, {'Label': 'car', 'xtl': 625.0, 'ytl': 493.0, 'xbr': 672.0, 'ybr': 528.0}, {'Label': 'car', 'xtl': 668.0, 'ytl': 558.0, 'xbr': 729.0, 'ybr': 603.0}, {'Label': 'car', 'xtl': 502.0, 'ytl': 428.0, 'xbr': 542.0, 'ybr': 460.0}, {'Label': 'car', 'xtl': 677.0, 'ytl': 694.0, 'xbr': 755.0, 'ybr': 763.0}, {'Label': 'car', 'xtl': 868.0, 'ytl': 779.0, 'xbr': 959.0, 'ybr': 846.0}, {'Label': 'car', 'xtl': 796.0, 'ytl': 907.0, 'xbr': 908.0, 'ybr': 1000.0}]
# [{'Label': 'truck', 'xtl': 995.0, 'ytl': 612.0, 'xbr': 1069.0, 'ybr': 677.0}, {'Label': 'truck', 'xtl': 1359.0, 'ytl': 723.0, 'xbr': 1593.0, 'ybr': 923.0}, {'Label': 'truck', 'xtl': 591.0, 'ytl': 298.0, 'xbr': 642.0, 'ybr': 350.0}, {'Label': 'car', 'xtl': 518.0, 'ytl': 453.0, 'xbr': 558.0, 'ybr': 485.0}, {'Label': 'car', 'xtl': 763.0, 'ytl': 451.0, 'xbr': 805.0, 'ybr': 484.0}, {'Label': 'car', 'xtl': 545.0, 'ytl': 496.0, 'xbr': 593.0, 'ybr': 535.0}, {'Label': 'truck', 'xtl': 674.16, 'ytl': 329.09, 'xbr': 711.16, 'ybr': 373.09}, {'Label': 'truck', 'xtl': 416.0, 'ytl': 361.0, 'xbr': 461.0, 'ybr': 423.0}, {'Label': 'car', 'xtl': 1352.4, 'ytl': 886.74, 'xbr': 1473.02, 'ybr': 973.72}, {'Label': 'truck', 'xtl': 973.0, 'ytl': 481.0, 'xbr': 1087.0, 'ybr': 617.0}, {'Label': 'truck', 'xtl': 807.0, 'ytl': 443.0, 'xbr': 882.0, 'ybr': 532.0}, {'Label': 'truck', 'xtl': 441.0, 'ytl': 442.0, 'xbr': 501.0, 'ybr': 526.0}, {'Label': 'bus', 'xtl': 731.0, 'ytl': 764.0, 'xbr': 917.0, 'ybr': 984.0}, {'Label': 'car', 'xtl': 769.0, 'ytl': 511.0, 'xbr': 818.0, 'ybr': 554.0}, {'Label': 'car', 'xtl': 872.0, 'ytl': 763.0, 'xbr': 959.0, 'ybr': 846.0}, {'Label': 'truck', 'xtl': 907.0, 'ytl': 540.0, 'xbr': 966.0, 'ybr': 599.0}, {'Label': 'truck', 'xtl': 1078.0, 'ytl': 664.0, 'xbr': 1159.0, 'ybr': 742.0}]
# [{'Label': 'truck', 'xtl': 671.0, 'ytl': 925.0, 'xbr': 892.0, 'ybr': 1075.0}, {'Label': 'car', 'xtl': 672.0, 'ytl': 554.0, 'xbr': 731.0, 'ybr': 602.0}, {'Label': 'car', 'xtl': 800.0, 'ytl': 475.0, 'xbr': 847.0, 'ybr': 513.0}, {'Label': 'car', 'xtl': 582.0, 'ytl': 448.0, 'xbr': 621.0, 'ybr': 479.0}, {'Label': 'truck', 'xtl': 1277.0, 'ytl': 695.0, 'xbr': 1463.0, 'ybr': 903.0}, {'Label': 'car', 'xtl': 543.0, 'ytl': 480.0, 'xbr': 588.0, 'ybr': 517.0}, {'Label': 'car', 'xtl': 738.0, 'ytl': 438.0, 'xbr': 777.0, 'ybr': 469.0}, {'Label': 'car', 'xtl': 896.0, 'ytl': 813.0, 'xbr': 985.0, 'ybr': 887.0}, {'Label': 'truck', 'xtl': 429.0, 'ytl': 388.0, 'xbr': 465.0, 'ybr': 438.0}, {'Label': 'truck', 'xtl': 1283.0, 'ytl': 805.0, 'xbr': 1409.0, 'ybr': 920.0}, {'Label': 'truck', 'xtl': 872.0, 'ytl': 440.0, 'xbr': 954.0, 'ybr': 528.0}, {'Label': 'car', 'xtl': 811.0, 'ytl': 531.0, 'xbr': 865.0, 'ybr': 574.0}, {'Label': 'car', 'xtl': 990.0, 'ytl': 616.0, 'xbr': 1056.0, 'ybr': 664.0}, {'Label': 'truck', 'xtl': 442.0, 'ytl': 443.0, 'xbr': 502.0, 'ybr': 518.0}, {'Label': 'car', 'xtl': 681.0, 'ytl': 729.0, 'xbr': 765.0, 'ybr': 807.0}, {'Label': 'truck', 'xtl': 689.0, 'ytl': 347.0, 'xbr': 734.0, 'ybr': 398.0}]
# [{'Label': 'truck', 'xtl': 456.0, 'ytl': 511.0, 'xbr': 527.0, 'ybr': 590.0}, {'Label': 'truck', 'xtl': 1293.0, 'ytl': 740.0, 'xbr': 1391.0, 'ybr': 823.0}, {'Label': 'car', 'xtl': 610.0, 'ytl': 606.0, 'xbr': 673.0, 'ybr': 670.0}, {'Label': 'truck', 'xtl': 690.37, 'ytl': 351.12, 'xbr': 728.37, 'ybr': 390.12}, {'Label': 'truck', 'xtl': 707.0, 'ytl': 996.0, 'xbr': 857.0, 'ybr': 1078.0}, {'Label': 'car', 'xtl': 787.39, 'ytl': 430.49, 'xbr': 820.39, 'ybr': 462.49}, {'Label': 'car', 'xtl': 581.0, 'ytl': 544.0, 'xbr': 636.0, 'ybr': 600.0}, {'Label': 'car', 'xtl': 691.0, 'ytl': 447.0, 'xbr': 729.0, 'ybr': 477.0}, {'Label': 'car', 'xtl': 755.0, 'ytl': 825.0, 'xbr': 867.0, 'ybr': 930.0}, {'Label': 'car', 'xtl': 538.0, 'ytl': 493.0, 'xbr': 581.0, 'ybr': 531.0}, {'Label': 'car', 'xtl': 943.0, 'ytl': 586.0, 'xbr': 1013.0, 'ybr': 640.0}, {'Label': 'car', 'xtl': 1108.0, 'ytl': 700.0, 'xbr': 1183.0, 'ybr': 757.0}, {'Label': 'car', 'xtl': 1169.0, 'ytl': 866.0, 'xbr': 1280.0, 'ybr': 944.0}, {'Label': 'car', 'xtl': 1031.0, 'ytl': 731.0, 'xbr': 1124.0, 'ybr': 800.0}, {'Label': 'truck', 'xtl': 807.0, 'ytl': 473.0, 'xbr': 855.0, 'ybr': 524.0}, {'Label': 'truck', 'xtl': 927.0, 'ytl': 475.0, 'xbr': 1027.0, 'ybr': 571.0}]
# [{'Label': 'car', 'xtl': 657.0, 'ytl': 542.0, 'xbr': 719.0, 'ybr': 593.0}, {'Label': 'car', 'xtl': 918.86, 'ytl': 815.19, 'xbr': 1022.68, 'ybr': 930.23}, {'Label': 'car', 'xtl': 698.6, 'ytl': 1035.45, 'xbr': 792.6, 'ybr': 1077.54}, {'Label': 'car', 'xtl': 710.18, 'ytl': 409.9, 'xbr': 747.18, 'ybr': 440.9}, {'Label': 'truck', 'xtl': 919.0, 'ytl': 486.0, 'xbr': 988.0, 'ybr': 557.0}, {'Label': 'truck', 'xtl': 735.0, 'ytl': 424.0, 'xbr': 779.0, 'ybr': 470.0}, {'Label': 'truck', 'xtl': 414.0, 'ytl': 349.0, 'xbr': 456.0, 'ybr': 397.0}, {'Label': 'truck', 'xtl': 1240.0, 'ytl': 666.0, 'xbr': 1405.0, 'ybr': 805.0}, {'Label': 'truck', 'xtl': 1452.0, 'ytl': 917.0, 'xbr': 1593.0, 'ybr': 1031.0}, {'Label': 'car', 'xtl': 987.0, 'ytl': 696.0, 'xbr': 1066.0, 'ybr': 753.0}, {'Label': 'car', 'xtl': 1226.0, 'ytl': 911.0, 'xbr': 1351.0, 'ybr': 999.0}, {'Label': 'car', 'xtl': 943.0, 'ytl': 581.0, 'xbr': 1005.0, 'ybr': 627.0}, {'Label': 'car', 'xtl': 669.0, 'ytl': 720.0, 'xbr': 748.0, 'ybr': 782.0}, {'Label': 'car', 'xtl': 536.0, 'ytl': 475.0, 'xbr': 584.0, 'ybr': 513.0}, {'Label': 'car', 'xtl': 584.0, 'ytl': 560.0, 'xbr': 635.0, 'ybr': 604.0}, {'Label': 'car', 'xtl': 612.0, 'ytl': 488.0, 'xbr': 660.0, 'ybr': 523.0}, {'Label': 'car', 'xtl': 565.0, 'ytl': 788.0, 'xbr': 651.0, 'ybr': 855.0}, {'Label': 'car', 'xtl': 565.0, 'ytl': 430.0, 'xbr': 607.0, 'ybr': 461.0}]
# [{'Label': 'car', 'xtl': 460.0, 'ytl': 512.0, 'xbr': 508.0, 'ybr': 554.0}, {'Label': 'car', 'xtl': 777.0, 'ytl': 861.0, 'xbr': 881.0, 'ybr': 949.0}, {'Label': 'car', 'xtl': 946.0, 'ytl': 661.0, 'xbr': 1026.0, 'ybr': 722.0}, {'Label': 'car', 'xtl': 542.0, 'ytl': 499.0, 'xbr': 592.0, 'ybr': 537.0}, {'Label': 'car', 'xtl': 608.0, 'ytl': 598.0, 'xbr': 670.0, 'ybr': 652.0}, {'Label': 'car', 'xtl': 612.0, 'ytl': 481.0, 'xbr': 658.0, 'ybr': 518.0}, {'Label': 'truck', 'xtl': 691.0, 'ytl': 349.0, 'xbr': 737.0, 'ybr': 395.0}, {'Label': 'truck', 'xtl': 691.0, 'ytl': 718.0, 'xbr': 777.0, 'ybr': 809.0}, {'Label': 'truck', 'xtl': 401.0, 'ytl': 327.0, 'xbr': 436.0, 'ybr': 378.0}, {'Label': 'car', 'xtl': 524.0, 'ytl': 449.0, 'xbr': 563.0, 'ybr': 479.0}, {'Label': 'truck', 'xtl': 1216.0, 'ytl': 701.0, 'xbr': 1442.0, 'ybr': 900.0}, {'Label': 'car', 'xtl': 934.3, 'ytl': 857.28, 'xbr': 1042.32, 'ybr': 969.51}, {'Label': 'truck', 'xtl': 907.0, 'ytl': 502.0, 'xbr': 1019.0, 'ybr': 616.0}, {'Label': 'truck', 'xtl': 1571.0, 'ytl': 833.0, 'xbr': 1873.0, 'ybr': 1074.0}, {'Label': 'truck', 'xtl': 896.0, 'ytl': 465.0, 'xbr': 977.0, 'ybr': 543.0}, {'Label': 'truck', 'xtl': 568.0, 'ytl': 725.0, 'xbr': 727.0, 'ybr': 943.0}]
# [{'Label': 'car', 'xtl': 973.0, 'ytl': 680.0, 'xbr': 1045.0, 'ybr': 736.0}, {'Label': 'truck', 'xtl': 1557.0, 'ytl': 999.0, 'xbr': 1678.0, 'ybr': 1080.0}, {'Label': 'truck', 'xtl': 590.0, 'ytl': 303.0, 'xbr': 637.0, 'ybr': 357.3}, {'Label': 'car', 'xtl': 766.91, 'ytl': 419.1, 'xbr': 798.1, 'ybr': 451.41}, {'Label': 'truck', 'xtl': 470.73, 'ytl': 527.37, 'xbr': 536.73, 'ybr': 586.37}, {'Label': 'truck', 'xtl': 653.0, 'ytl': 344.0, 'xbr': 694.0, 'ybr': 394.0}, {'Label': 'car', 'xtl': 1006.0, 'ytl': 626.0, 'xbr': 1076.0, 'ybr': 679.0}, {'Label': 'truck', 'xtl': 735.0, 'ytl': 364.0, 'xbr': 787.0, 'ybr': 424.0}, {'Label': 'truck', 'xtl': 451.0, 'ytl': 315.0, 'xbr': 483.0, 'ybr': 359.0}, {'Label': 'truck', 'xtl': 789.0, 'ytl': 438.0, 'xbr': 842.0, 'ybr': 493.0}, {'Label': 'truck', 'xtl': 620.0, 'ytl': 361.0, 'xbr': 667.0, 'ybr': 415.0}, {'Label': 'truck', 'xtl': 833.0, 'ytl': 449.0, 'xbr': 932.0, 'ybr': 563.0}, {'Label': 'car', 'xtl': 1572.0, 'ytl': 937.0, 'xbr': 1707.0, 'ybr': 1023.0}, {'Label': 'car', 'xtl': 1199.0, 'ytl': 772.0, 'xbr': 1289.0, 'ybr': 836.0}, {'Label': 'car', 'xtl': 748.0, 'ytl': 843.0, 'xbr': 852.0, 'ybr': 934.0}, {'Label': 'car', 'xtl': 677.0, 'ytl': 557.0, 'xbr': 734.0, 'ybr': 598.0}, {'Label': 'car', 'xtl': 571.0, 'ytl': 538.0, 'xbr': 623.0, 'ybr': 584.0}, {'Label': 'car', 'xtl': 513.0, 'ytl': 445.0, 'xbr': 557.0, 'ybr': 481.0}, {'Label': 'car', 'xtl': 1371.0, 'ytl': 1032.0, 'xbr': 1508.0, 'ybr': 1080.0}, {'Label': 'car', 'xtl': 702.0, 'ytl': 412.0, 'xbr': 738.0, 'ybr': 444.0}]
# [{'Label': 'bus', 'xtl': 694.0, 'ytl': 669.0, 'xbr': 841.0, 'ybr': 864.0}, {'Label': 'bus', 'xtl': 847.0, 'ytl': 480.0, 'xbr': 916.0, 'ybr': 558.0}, {'Label': 'truck', 'xtl': 1459.7, 'ytl': 829.0, 'xbr': 1581.0, 'ybr': 907.7}, {'Label': 'car', 'xtl': 738.0, 'ytl': 435.0, 'xbr': 773.0, 'ybr': 464.0}, {'Label': 'car', 'xtl': 572.0, 'ytl': 431.0, 'xbr': 611.0, 'ybr': 462.0}, {'Label': 'car', 'xtl': 531.0, 'ytl': 472.0, 'xbr': 576.0, 'ybr': 508.0}, {'Label': 'car', 'xtl': 794.0, 'ytl': 472.0, 'xbr': 838.0, 'ybr': 509.0}, {'Label': 'car', 'xtl': 824.0, 'ytl': 554.0, 'xbr': 884.0, 'ybr': 599.0}, {'Label': 'car', 'xtl': 552.0, 'ytl': 761.0, 'xbr': 634.0, 'ybr': 826.0}, {'Label': 'truck', 'xtl': 842.0, 'ytl': 954.0, 'xbr': 972.0, 'ybr': 1073.0}, {'Label': 'truck', 'xtl': 1423.0, 'ytl': 892.0, 'xbr': 1574.0, 'ybr': 1038.0}, {'Label': 'truck', 'xtl': 692.0, 'ytl': 386.0, 'xbr': 726.0, 'ybr': 427.0}, {'Label': 'truck', 'xtl': 459.0, 'ytl': 487.0, 'xbr': 511.0, 'ybr': 563.0}, {'Label': 'car', 'xtl': 663.62, 'ytl': 424.5, 'xbr': 699.6, 'ybr': 456.91}]
# [{'Label': 'car', 'xtl': 628.51, 'ytl': 391.13, 'xbr': 663.82, 'ybr': 423.38}, {'Label': 'truck', 'xtl': 1204.0, 'ytl': 629.0, 'xbr': 1372.0, 'ybr': 776.0}, {'Label': 'truck', 'xtl': 1154.0, 'ytl': 711.0, 'xbr': 1248.0, 'ybr': 800.0}, {'Label': 'car', 'xtl': 708.0, 'ytl': 411.0, 'xbr': 744.0, 'ybr': 441.0}, {'Label': 'car', 'xtl': 493.0, 'ytl': 402.0, 'xbr': 527.0, 'ybr': 433.0}, {'Label': 'car', 'xtl': 545.0, 'ytl': 394.0, 'xbr': 583.0, 'ybr': 427.0}, {'Label': 'car', 'xtl': 513.0, 'ytl': 448.0, 'xbr': 554.0, 'ybr': 481.0}, {'Label': 'car', 'xtl': 440.0, 'ytl': 422.0, 'xbr': 481.0, 'ybr': 455.0}, {'Label': 'car', 'xtl': 814.0, 'ytl': 492.0, 'xbr': 858.0, 'ybr': 524.0}, {'Label': 'car', 'xtl': 533.0, 'ytl': 468.0, 'xbr': 586.0, 'ybr': 511.0}, {'Label': 'car', 'xtl': 846.0, 'ytl': 577.0, 'xbr': 910.0, 'ybr': 624.0}, {'Label': 'car', 'xtl': 949.0, 'ytl': 587.0, 'xbr': 1011.0, 'ybr': 628.0}, {'Label': 'car', 'xtl': 1277.0, 'ytl': 941.0, 'xbr': 1416.0, 'ybr': 1042.0}]
# ...
# [{'Label': 'car', 'xtl': 808.0, 'ytl': 494.0, 'xbr': 855.0, 'ybr': 532.0}, {'Label': 'truck', 'xtl': 1218.0, 'ytl': 771.0, 'xbr': 1324.0, 'ybr': 862.0}, {'Label': 'truck', 'xtl': 909.0, 'ytl': 467.0, 'xbr': 1002.0, 'ybr': 560.0}, {'Label': 'truck', 'xtl': 560.0, 'ytl': 497.0, 'xbr': 638.0, 'ybr': 595.0}, {'Label': 'truck', 'xtl': 454.0, 'ytl': 417.0, 'xbr': 492.0, 'ybr': 459.0}, {'Label': 'truck', 'xtl': 679.0, 'ytl': 346.0, 'xbr': 726.0, 'ybr': 393.0}, {'Label': 'truck', 'xtl': 982.0, 'ytl': 927.0, 'xbr': 1109.0, 'ybr': 1040.0}, {'Label': 'car', 'xtl': 578.0, 'ytl': 456.0, 'xbr': 616.0, 'ybr': 489.0}, {'Label': 'truck', 'xtl': 410.0, 'ytl': 371.0, 'xbr': 450.0, 'ybr': 408.0}, {'Label': 'truck', 'xtl': 681.77, 'ytl': 378.88, 'xbr': 721.05, 'ybr': 420.96}, {'Label': 'car', 'xtl': 714.0, 'ytl': 423.0, 'xbr': 749.0, 'ybr': 452.0}, {'Label': 'car', 'xtl': 1129.0, 'ytl': 817.0, 'xbr': 1231.0, 'ybr': 899.0}, {'Label': 'car', 'xtl': 686.0, 'ytl': 721.0, 'xbr': 769.0, 'ybr': 785.0}, {'Label': 'car', 'xtl': 712.0, 'ytl': 598.0, 'xbr': 782.0, 'ybr': 653.0}, {'Label': 'car', 'xtl': 564.0, 'ytl': 431.0, 'xbr': 602.0, 'ybr': 463.0}, {'Label': 'truck', 'xtl': 1612.0, 'ytl': 874.0, 'xbr': 1862.0, 'ybr': 1080.0}, {'Label': 'truck', 'xtl': 578.0, 'ytl': 750.0, 'xbr': 693.0, 'ybr': 918.0}, {'Label': 'car', 'xtl': 507.0, 'ytl': 441.0, 'xbr': 549.0, 'ybr': 476.0}]
# [{'Label': 'car', 'xtl': 639.0, 'ytl': 643.0, 'xbr': 709.0, 'ybr': 702.0}, {'Label': 'car', 'xtl': 526.0, 'ytl': 483.0, 'xbr': 571.0, 'ybr': 520.0}, {'Label': 'car', 'xtl': 697.0, 'ytl': 411.0, 'xbr': 733.0, 'ybr': 443.0}, {'Label': 'car', 'xtl': 673.0, 'ytl': 591.0, 'xbr': 733.0, 'ybr': 636.0}, {'Label': 'car', 'xtl': 981.0, 'ytl': 933.0, 'xbr': 1103.0, 'ybr': 1027.0}, {'Label': 'truck', 'xtl': 640.0, 'ytl': 321.0, 'xbr': 681.0, 'ybr': 368.0}, {'Label': 'truck', 'xtl': 775.0, 'ytl': 401.0, 'xbr': 829.0, 'ybr': 463.0}, {'Label': 'truck', 'xtl': 401.0, 'ytl': 326.0, 'xbr': 440.0, 'ybr': 381.0}, {'Label': 'truck', 'xtl': 967.0, 'ytl': 499.0, 'xbr': 1086.0, 'ybr': 609.0}, {'Label': 'truck', 'xtl': 588.0, 'ytl': 797.0, 'xbr': 782.0, 'ybr': 1039.0}, {'Label': 'truck', 'xtl': 1489.0, 'ytl': 756.0, 'xbr': 1753.0, 'ybr': 1025.0}, {'Label': 'car', 'xtl': 675.0, 'ytl': 718.0, 'xbr': 754.0, 'ybr': 780.0}, {'Label': 'car', 'xtl': 518.0, 'ytl': 667.0, 'xbr': 590.0, 'ybr': 722.0}]
# [{'Label': 'truck', 'xtl': 618.0, 'ytl': 312.0, 'xbr': 658.0, 'ybr': 358.0}, {'Label': 'car', 'xtl': 924.47, 'ytl': 865.6, 'xbr': 1055.7, 'ybr': 969.7}, {'Label': 'truck', 'xtl': 411.0, 'ytl': 377.47, 'xbr': 454.49, 'ybr': 423.77}, {'Label': 'truck', 'xtl': 863.0, 'ytl': 437.0, 'xbr': 961.0, 'ybr': 541.0}, {'Label': 'truck', 'xtl': 544.0, 'ytl': 469.0, 'xbr': 624.0, 'ybr': 575.0}, {'Label': 'car', 'xtl': 662.0, 'ytl': 384.0, 'xbr': 699.0, 'ybr': 413.0}, {'Label': 'car', 'xtl': 713.0, 'ytl': 466.0, 'xbr': 754.0, 'ybr': 499.0}, {'Label': 'truck', 'xtl': 504.0, 'ytl': 585.0, 'xbr': 614.0, 'ybr': 739.0}, {'Label': 'truck', 'xtl': 1274.0, 'ytl': 758.0, 'xbr': 1474.0, 'ybr': 942.0}, {'Label': 'truck', 'xtl': 710.0, 'ytl': 355.0, 'xbr': 766.0, 'ybr': 421.0}, {'Label': 'truck', 'xtl': 497.0, 'ytl': 408.0, 'xbr': 559.0, 'ybr': 479.0}]
# [{'Label': 'car', 'xtl': 718.0, 'ytl': 766.0, 'xbr': 807.0, 'ybr': 856.0}, {'Label': 'car', 'xtl': 573.0, 'ytl': 552.0, 'xbr': 633.0, 'ybr': 600.0}, {'Label': 'truck', 'xtl': 793.0, 'ytl': 393.0, 'xbr': 872.0, 'ybr': 478.0}, {'Label': 'truck', 'xtl': 627.0, 'ytl': 344.0, 'xbr': 669.0, 'ybr': 386.0}, {'Label': 'bus', 'xtl': 707.0, 'ytl': 418.0, 'xbr': 774.0, 'ybr': 494.0}, {'Label': 'car', 'xtl': 826.0, 'ytl': 724.0, 'xbr': 917.0, 'ybr': 818.0}, {'Label': 'truck', 'xtl': 460.0, 'ytl': 353.0, 'xbr': 502.0, 'ybr': 408.0}, {'Label': 'truck', 'xtl': 610.0, 'ytl': 299.0, 'xbr': 651.0, 'ybr': 346.0}, {'Label': 'truck', 'xtl': 568.0, 'ytl': 780.0, 'xbr': 680.0, 'ybr': 911.0}, {'Label': 'car', 'xtl': 673.0, 'ytl': 429.0, 'xbr': 714.0, 'ybr': 463.0}, {'Label': 'car', 'xtl': 438.0, 'ytl': 456.0, 'xbr': 484.0, 'ybr': 495.0}, {'Label': 'car', 'xtl': 527.0, 'ytl': 489.0, 'xbr': 576.0, 'ybr': 528.0}, {'Label': 'car', 'xtl': 993.0, 'ytl': 933.0, 'xbr': 1116.0, 'ybr': 1032.0}, {'Label': 'car', 'xtl': 907.0, 'ytl': 553.0, 'xbr': 972.0, 'ybr': 599.0}, {'Label': 'car', 'xtl': 794.0, 'ytl': 897.0, 'xbr': 908.0, 'ybr': 994.0}, {'Label': 'car', 'xtl': 719.0, 'ytl': 619.0, 'xbr': 778.0, 'ybr': 670.0}]
# [{'Label': 'truck', 'xtl': 728.0, 'ytl': 733.0, 'xbr': 962.0, 'ybr': 1049.0}, {'Label': 'bus', 'xtl': 510.0, 'ytl': 340.0, 'xbr': 551.0, 'ybr': 391.0}, {'Label': 'bus', 'xtl': 870.03, 'ytl': 719.4, 'xbr': 1033.4, 'ybr': 921.02}, {'Label': 'truck', 'xtl': 925.2, 'ytl': 481.5, 'xbr': 999.0, 'ybr': 570.0}, {'Label': 'car', 'xtl': 719.24, 'ytl': 427.0, 'xbr': 753.7, 'ybr': 455.45}, {'Label': 'car', 'xtl': 701.16, 'ytl': 461.27, 'xbr': 740.16, 'ybr': 495.27}, {'Label': 'car', 'xtl': 1295.0, 'ytl': 985.0, 'xbr': 1432.0, 'ybr': 1073.0}, {'Label': 'car', 'xtl': 1188.0, 'ytl': 779.0, 'xbr': 1283.0, 'ybr': 845.0}, {'Label': 'car', 'xtl': 747.0, 'ytl': 653.0, 'xbr': 815.0, 'ybr': 707.0}, {'Label': 'car', 'xtl': 584.0, 'ytl': 573.0, 'xbr': 643.0, 'ybr': 623.0}, {'Label': 'car', 'xtl': 961.0, 'ytl': 671.0, 'xbr': 1034.0, 'ybr': 725.0}, {'Label': 'car', 'xtl': 803.0, 'ytl': 548.0, 'xbr': 866.0, 'ybr': 595.0}, {'Label': 'car', 'xtl': 671.0, 'ytl': 689.0, 'xbr': 745.0, 'ybr': 759.0}, {'Label': 'car', 'xtl': 565.0, 'ytl': 765.0, 'xbr': 661.0, 'ybr': 855.0}, {'Label': 'car', 'xtl': 534.0, 'ytl': 478.0, 'xbr': 579.0, 'ybr': 512.0}, {'Label': 'car', 'xtl': 567.0, 'ytl': 433.0, 'xbr': 609.0, 'ybr': 466.0}, {'Label': 'truck', 'xtl': 1055.0, 'ytl': 589.0, 'xbr': 1123.0, 'ybr': 651.0}, {'Label': 'truck', 'xtl': 1327.0, 'ytl': 699.0, 'xbr': 1542.0, 'ybr': 930.0}, {'Label': 'truck', 'xtl': 1345.0, 'ytl': 751.0, 'xbr': 1665.0, 'ybr': 1070.0}, {'Label': 'truck', 'xtl': 905.0, 'ytl': 538.0, 'xbr': 962.0, 'ybr': 598.0}, {'Label': 'car', 'xtl': 1066.0, 'ytl': 666.0, 'xbr': 1145.0, 'ybr': 731.0}, {'Label': 'car', 'xtl': 818.0, 'ytl': 496.0, 'xbr': 857.0, 'ybr': 531.0}, {'Label': 'truck', 'xtl': 845.72, 'ytl': 497.0, 'xbr': 896.39, 'ybr': 551.6}]
# [{'Label': 'car', 'xtl': 633.0, 'ytl': 514.0, 'xbr': 685.0, 'ybr': 557.0}, {'Label': 'car', 'xtl': 678.0, 'ytl': 442.0, 'xbr': 716.0, 'ybr': 472.0}, {'Label': 'car', 'xtl': 1563.0, 'ytl': 1034.0, 'xbr': 1702.0, 'ybr': 1080.0}, {'Label': 'truck', 'xtl': 411.0, 'ytl': 387.0, 'xbr': 450.0, 'ybr': 424.0}, {'Label': 'truck', 'xtl': 1190.0, 'ytl': 695.0, 'xbr': 1417.0, 'ybr': 888.0}, {'Label': 'car', 'xtl': 932.0, 'ytl': 645.0, 'xbr': 997.0, 'ybr': 696.0}, {'Label': 'car', 'xtl': 615.0, 'ytl': 906.0, 'xbr': 726.0, 'ybr': 995.0}, {'Label': 'truck', 'xtl': 722.45, 'ytl': 356.43, 'xbr': 770.15, 'ybr': 418.16}, {'Label': 'truck', 'xtl': 740.0, 'ytl': 406.0, 'xbr': 805.0, 'ybr': 480.0}, {'Label': 'car', 'xtl': 955.0, 'ytl': 599.0, 'xbr': 1019.0, 'ybr': 645.0}, {'Label': 'truck', 'xtl': 563.0, 'ytl': 527.0, 'xbr': 620.0, 'ybr': 593.0}, {'Label': 'car', 'xtl': 1185.0, 'ytl': 876.0, 'xbr': 1302.0, 'ybr': 955.0}, {'Label': 'car', 'xtl': 431.0, 'ytl': 421.0, 'xbr': 476.0, 'ybr': 459.0}, {'Label': 'car', 'xtl': 510.0, 'ytl': 456.0, 'xbr': 551.0, 'ybr': 489.0}, {'Label': 'truck', 'xtl': 1687.0, 'ytl': 933.0, 'xbr': 1910.0, 'ybr': 1080.0}, {'Label': 'truck', 'xtl': 665.0, 'ytl': 355.0, 'xbr': 715.0, 'ybr': 422.0}, {'Label': 'car', 'xtl': 564.0, 'ytl': 432.0, 'xbr': 601.0, 'ybr': 464.0}]
# [{'Label': 'car', 'xtl': 575.0, 'ytl': 560.0, 'xbr': 632.0, 'ybr': 611.0}, {'Label': 'truck', 'xtl': 694.47, 'ytl': 357.1, 'xbr': 740.26, 'ybr': 398.96}, {'Label': 'car', 'xtl': 1379.0, 'ytl': 880.5, 'xbr': 1506.0, 'ybr': 987.0}, {'Label': 'truck', 'xtl': 750.84, 'ytl': 395.29, 'xbr': 804.0, 'ybr': 443.0}, {'Label': 'truck', 'xtl': 952.0, 'ytl': 493.0, 'xbr': 1061.0, 'ybr': 598.0}, {'Label': 'truck', 'xtl': 1189.0, 'ytl': 640.0, 'xbr': 1354.0, 'ybr': 777.0}, {'Label': 'truck', 'xtl': 596.0, 'ytl': 792.0, 'xbr': 694.0, 'ybr': 940.0}, {'Label': 'truck', 'xtl': 644.0, 'ytl': 984.0, 'xbr': 812.0, 'ybr': 1080.0}, {'Label': 'truck', 'xtl': 552.0, 'ytl': 684.0, 'xbr': 630.0, 'ybr': 766.0}, {'Label': 'truck', 'xtl': 628.0, 'ytl': 338.0, 'xbr': 668.0, 'ybr': 385.0}, {'Label': 'car', 'xtl': 1103.0, 'ytl': 701.0, 'xbr': 1196.0, 'ybr': 772.0}, {'Label': 'car', 'xtl': 808.0, 'ytl': 734.0, 'xbr': 891.0, 'ybr': 800.0}, {'Label': 'car', 'xtl': 619.0, 'ytl': 491.0, 'xbr': 672.0, 'ybr': 532.0}, {'Label': 'car', 'xtl': 712.0, 'ytl': 610.0, 'xbr': 781.0, 'ybr': 661.0}, {'Label': 'car', 'xtl': 962.88, 'ytl': 903.2, 'xbr': 1066.4, 'ybr': 991.68}, {'Label': 'car', 'xtl': 958.0, 'ytl': 599.0, 'xbr': 1017.0, 'ybr': 642.0}, {'Label': 'car', 'xtl': 525.0, 'ytl': 466.0, 'xbr': 571.0, 'ybr': 500.0}, {'Label': 'car', 'xtl': 796.0, 'ytl': 484.0, 'xbr': 840.0, 'ybr': 518.0}, {'Label': 'car', 'xtl': 754.0, 'ytl': 817.0, 'xbr': 854.0, 'ybr': 912.0}, {'Label': 'car', 'xtl': 700.0, 'ytl': 468.0, 'xbr': 741.0, 'ybr': 497.0}, {'Label': 'car', 'xtl': 552.0, 'ytl': 416.0, 'xbr': 590.0, 'ybr': 447.0}, {'Label': 'car', 'xtl': 755.0, 'ytl': 452.0, 'xbr': 791.0, 'ybr': 482.0}]
# [{'Label': 'truck', 'xtl': 643.7, 'ytl': 319.0, 'xbr': 681.0, 'ybr': 358.6}, {'Label': 'car', 'xtl': 723.0, 'ytl': 789.0, 'xbr': 815.0, 'ybr': 864.0}, {'Label': 'car', 'xtl': 488.0, 'ytl': 570.0, 'xbr': 548.0, 'ybr': 628.0}, {'Label': 'car', 'xtl': 437.0, 'ytl': 457.0, 'xbr': 480.0, 'ybr': 490.0}, {'Label': 'car', 'xtl': 764.0, 'ytl': 456.0, 'xbr': 806.0, 'ybr': 489.0}, {'Label': 'truck', 'xtl': 680.0, 'ytl': 350.0, 'xbr': 728.0, 'ybr': 403.0}, {'Label': 'truck', 'xtl': 945.0, 'ytl': 540.0, 'xbr': 1075.0, 'ybr': 664.0}, {'Label': 'truck', 'xtl': 764.06, 'ytl': 412.7, 'xbr': 797.06, 'ybr': 444.93}, {'Label': 'truck', 'xtl': 894.0, 'ytl': 993.0, 'xbr': 1029.0, 'ybr': 1076.0}]
# [{'Label': 'truck', 'xtl': 899.0, 'ytl': 447.0, 'xbr': 999.0, 'ybr': 563.0}, {'Label': 'truck', 'xtl': 785.0, 'ytl': 435.0, 'xbr': 854.0, 'ybr': 513.0}, {'Label': 'car', 'xtl': 769.0, 'ytl': 814.0, 'xbr': 861.0, 'ybr': 894.0}, {'Label': 'bus', 'xtl': 441.0, 'ytl': 318.0, 'xbr': 477.0, 'ybr': 361.0}, {'Label': 'truck', 'xtl': 850.0, 'ytl': 511.0, 'xbr': 901.0, 'ybr': 560.0}, {'Label': 'truck', 'xtl': 550.0, 'ytl': 486.0, 'xbr': 620.0, 'ybr': 562.0}, {'Label': 'car', 'xtl': 500.0, 'ytl': 632.0, 'xbr': 561.0, 'ybr': 686.0}, {'Label': 'car', 'xtl': 625.0, 'ytl': 623.0, 'xbr': 694.0, 'ybr': 682.0}, {'Label': 'car', 'xtl': 689.0, 'ytl': 405.0, 'xbr': 725.0, 'ybr': 432.0}, {'Label': 'car', 'xtl': 511.0, 'ytl': 459.0, 'xbr': 555.0, 'ybr': 493.0}, {'Label': 'car', 'xtl': 1105.0, 'ytl': 633.0, 'xbr': 1175.0, 'ybr': 683.0}, {'Label': 'car', 'xtl': 734.0, 'ytl': 437.0, 'xbr': 778.0, 'ybr': 473.0}, {'Label': 'truck', 'xtl': 599.0, 'ytl': 319.0, 'xbr': 639.0, 'ybr': 366.0}, {'Label': 'truck', 'xtl': 1352.0, 'ytl': 840.0, 'xbr': 1495.0, 'ybr': 988.0}, {'Label': 'truck', 'xtl': 1532.0, 'ytl': 827.0, 'xbr': 1836.0, 'ybr': 1065.0}, {'Label': 'truck', 'xtl': 405.0, 'ytl': 335.0, 'xbr': 445.0, 'ybr': 389.0}]
# [{'Label': 'truck', 'xtl': 536.0, 'ytl': 653.0, 'xbr': 694.0, 'ybr': 900.0}, {'Label': 'truck', 'xtl': 645.0, 'ytl': 353.0, 'xbr': 699.0, 'ybr': 403.0}, {'Label': 'truck', 'xtl': 396.0, 'ytl': 304.0, 'xbr': 434.0, 'ybr': 350.0}, {'Label': 'truck', 'xtl': 443.0, 'ytl': 436.0, 'xbr': 488.0, 'ybr': 494.0}, {'Label': 'truck', 'xtl': 473.0, 'ytl': 517.0, 'xbr': 541.0, 'ybr': 586.0}, {'Label': 'truck', 'xtl': 622.0, 'ytl': 309.0, 'xbr': 666.0, 'ybr': 362.0}, {'Label': 'car', 'xtl': 676.0, 'ytl': 573.0, 'xbr': 734.0, 'ybr': 621.0}, {'Label': 'car', 'xtl': 597.0, 'ytl': 483.0, 'xbr': 645.0, 'ybr': 521.0}, {'Label': 'bus', 'xtl': 620.0, 'ytl': 602.0, 'xbr': 743.0, 'ybr': 750.0}, {'Label': 'car', 'xtl': 587.0, 'ytl': 577.0, 'xbr': 648.0, 'ybr': 621.0}]
# [{'Label': 'car', 'xtl': 799.0, 'ytl': 538.0, 'xbr': 860.0, 'ybr': 584.0}, {'Label': 'truck', 'xtl': 897.0, 'ytl': 546.0, 'xbr': 957.0, 'ybr': 601.0}, {'Label': 'truck', 'xtl': 730.0, 'ytl': 370.0, 'xbr': 787.0, 'ybr': 431.0}, {'Label': 'truck', 'xtl': 947.0, 'ytl': 479.0, 'xbr': 1064.0, 'ybr': 599.0}, {'Label': 'truck', 'xtl': 451.0, 'ytl': 447.0, 'xbr': 523.0, 'ybr': 557.0}, {'Label': 'car', 'xtl': 667.0, 'ytl': 429.0, 'xbr': 704.0, 'ybr': 460.0}, {'Label': 'car', 'xtl': 647.0, 'ytl': 658.0, 'xbr': 721.0, 'ybr': 732.0}, {'Label': 'car', 'xtl': 768.0, 'ytl': 503.0, 'xbr': 819.0, 'ybr': 538.0}, {'Label': 'car', 'xtl': 543.0, 'ytl': 580.0, 'xbr': 601.0, 'ybr': 631.0}, {'Label': 'car', 'xtl': 1378.0, 'ytl': 1009.0, 'xbr': 1538.0, 'ybr': 1080.0}, {'Label': 'car', 'xtl': 524.0, 'ytl': 466.0, 'xbr': 571.0, 'ybr': 504.0}, {'Label': 'car', 'xtl': 623.0, 'ytl': 516.0, 'xbr': 680.0, 'ybr': 555.0}, {'Label': 'car', 'xtl': 950.0, 'ytl': 659.0, 'xbr': 1023.0, 'ybr': 711.0}]
# [{'Label': 'truck', 'xtl': 831.0, 'ytl': 429.0, 'xbr': 904.0, 'ybr': 504.0}, {'Label': 'truck', 'xtl': 954.0, 'ytl': 535.0, 'xbr': 1010.0, 'ybr': 586.0}, {'Label': 'truck', 'xtl': 462.0, 'ytl': 493.0, 'xbr': 535.0, 'ybr': 585.0}, {'Label': 'truck', 'xtl': 762.0, 'ytl': 826.0, 'xbr': 865.0, 'ybr': 935.0}, {'Label': 'truck', 'xtl': 655.0, 'ytl': 368.0, 'xbr': 694.0, 'ybr': 405.0}, {'Label': 'car', 'xtl': 657.0, 'ytl': 534.0, 'xbr': 713.0, 'ybr': 581.0}, {'Label': 'car', 'xtl': 771.0, 'ytl': 514.0, 'xbr': 819.0, 'ybr': 549.0}, {'Label': 'car', 'xtl': 542.0, 'ytl': 495.0, 'xbr': 594.0, 'ybr': 539.0}, {'Label': 'car', 'xtl': 686.0, 'ytl': 442.0, 'xbr': 724.0, 'ybr': 471.0}, {'Label': 'car', 'xtl': 615.0, 'ytl': 388.0, 'xbr': 652.0, 'ybr': 416.0}, {'Label': 'car', 'xtl': 965.8, 'ytl': 874.7, 'xbr': 1088.0, 'ybr': 995.4}, {'Label': 'truck', 'xtl': 413.0, 'ytl': 376.0, 'xbr': 458.0, 'ybr': 421.0}, {'Label': 'car', 'xtl': 649.96, 'ytl': 416.5, 'xbr': 681.1, 'ybr': 438.71}]
# [{'Label': 'truck', 'xtl': 404.0, 'ytl': 348.0, 'xbr': 449.0, 'ybr': 400.0}, {'Label': 'truck', 'xtl': 913.0, 'ytl': 480.0, 'xbr': 993.0, 'ybr': 564.0}, {'Label': 'truck', 'xtl': 642.0, 'ytl': 977.0, 'xbr': 850.0, 'ybr': 1079.0}, {'Label': 'car', 'xtl': 757.0, 'ytl': 668.0, 'xbr': 836.0, 'ybr': 726.0}, {'Label': 'car', 'xtl': 474.0, 'ytl': 385.0, 'xbr': 508.0, 'ybr': 413.0}, {'Label': 'car', 'xtl': 744.0, 'ytl': 445.0, 'xbr': 784.0, 'ybr': 477.0}, {'Label': 'car', 'xtl': 685.0, 'ytl': 446.0, 'xbr': 724.0, 'ybr': 474.0}, {'Label': 'car', 'xtl': 500.0, 'ytl': 423.0, 'xbr': 537.0, 'ybr': 451.0}, {'Label': 'car', 'xtl': 1318.0, 'ytl': 987.0, 'xbr': 1458.0, 'ybr': 1073.0}, {'Label': 'car', 'xtl': 893.0, 'ytl': 623.0, 'xbr': 960.0, 'ybr': 670.0}, {'Label': 'car', 'xtl': 1125.0, 'ytl': 823.0, 'xbr': 1225.0, 'ybr': 893.0}, {'Label': 'car', 'xtl': 619.0, 'ytl': 618.0, 'xbr': 690.0, 'ybr': 679.0}, {'Label': 'car', 'xtl': 856.0, 'ytl': 523.0, 'xbr': 904.0, 'ybr': 558.0}, {'Label': 'car', 'xtl': 745.0, 'ytl': 491.0, 'xbr': 796.0, 'ybr': 534.0}, {'Label': 'truck', 'xtl': 1418.31, 'ytl': 805.37, 'xbr': 1531.95, 'ybr': 900.77}, {'Label': 'car', 'xtl': 694.0, 'ytl': 722.0, 'xbr': 786.0, 'ybr': 816.0}, {'Label': 'car', 'xtl': 819.0, 'ytl': 744.0, 'xbr': 906.0, 'ybr': 809.0}, {'Label': 'truck', 'xtl': 1095.0, 'ytl': 554.0, 'xbr': 1254.0, 'ybr': 711.0}, {'Label': 'truck', 'xtl': 946.0, 'ytl': 569.0, 'xbr': 1014.0, 'ybr': 639.0}, {'Label': 'truck', 'xtl': 455.0, 'ytl': 457.0, 'xbr': 524.0, 'ybr': 543.0}]
# Result
